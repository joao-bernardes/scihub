# %%
import pandas as pd
import numpy as np

# %%
statistics2017 = pd.read_csv("./../../data/sample/2017.statistics.sample.with_missing_cities_continents.csv")
statistics2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500000 entries, 0 to 1499999
# Data columns (total 11 columns):
# DOI           1500000 non-null object
# IPID          1500000 non-null int64
# city          1394066 non-null object
# country       1468489 non-null object
# date          1500000 non-null object
# is_oa         1480851 non-null object
# lat           1386787 non-null float64
# lon           1386787 non-null float64
# userID        1500000 non-null int64
# continent     1467987 non-null object
# DOI_prefix    1500000 non-null float64
# dtypes: float64(3), int64(2), object(6)
# memory usage: 125.9+ MB

# %%
table1 = statistics2017.loc[statistics2017.continent == "Asia",("country","DOI")].groupby('country').count().sort_values(by='DOI',ascending = False).head(25)
table1 = table1.rename({"DOI": "Downloads"}, axis = "columns")
table1
# Out:
#                       Downloads
# country
# China                    243363
# India                    132886
# Iran                      71958
# Indonesia                 59517
# Russia                    37784
# South Korea               26428
# Malaysia                  24893
# Turkey                    20258
# Pakistan                  19831
# Taiwan                    19597
# Hong Kong                 15968
# Singapore                 13914
# Japan                     12858
# Philippines               12357
# Vietnam                   12263
# Thailand                   6509
# Iraq                       4168
# Bangladesh                 3594
# Saudi Arabia               2818
# Sri Lanka                  2694
# Israel                     2521
# Jordan                     2158
# Nepal                      1500
# United Arab Emirates       1225
# Syria                      1113

# %%
table2 = statistics2017.loc[statistics2017.continent == "Asia",("country","city","DOI")].groupby(['country','city']).count().sort_values(by='DOI',ascending = False).head(25)
table2 = table2.rename({"DOI": "Downloads"}, axis = "columns")
table2
# Out:
#                            Downloads
# country     city
# Iran        Tehran             40927
# China       Beijing            36000
# Indonesia   Gambir             32378
# China       Shanghai           28426
#             Dingxi Shi         21708
# South Korea Seoul              21282
# India       Gugal Pimpari      18614
# Russia      Moskva             18532
# Singapore   Singapore          13914
# China       Guangzhou Shi      13453
#             Nanjing Shi        12591
# India       New Delhi          10317
#             Chennai            10145
# China       Wuhan Shi           9889
#             Hangzhou Shi        9500
# India       Bengaluru           9384
# Iran        Tiran               9360
# China       Chengdu Shi         9112
# Taiwan      中正區                 8543
# Turkey      Fatih               8406
# India       Hyderabad           7438
# China       Changsha Shi        7403
# India       Mumbai              7309
# Vietnam     Hanoi               6931
# ...

# %%
print (table2.to_latex())
# Out:
# \begin{tabular}{llr}
# \toprule
#       &         &  Downloads \\
# country & city &            \\
# \midrule
# Iran & Tehran &      40927 \\
# China & Beijing &      36000 \\
# Indonesia & Gambir &      32378 \\
# China & Shanghai &      28426 \\
#       & Dingxi Shi &      21708 \\
# South Korea & Seoul &      21282 \\
# India & Gugal Pimpari &      18614 \\
# Russia & Moskva &      18532 \\
# Singapore & Singapore &      13914 \\
# China & Guangzhou Shi &      13453 \\
#       & Nanjing Shi &      12591 \\
# India & New Delhi &      10317 \\
#       & Chennai &      10145 \\
# China & Wuhan Shi &       9889 \\
#       & Hangzhou Shi &       9500 \\
# India & Bengaluru &       9384 \\
# Iran & Tiran &       9360 \\
# China & Chengdu Shi &       9112 \\
# Taiwan & 中正區 &       8543 \\
# Turkey & Fatih &       8406 \\
# India & Hyderabad &       7438 \\
# China & Changsha Shi &       7403 \\
# India & Mumbai &       7309 \\
# Vietnam & Hanoi &       6931 \\
# ...

# %%
#Establishing 'Top Countries' by downloads:

topByCityCountry = statistics2017.loc[statistics2017.continent == "Asia",:].groupby("country").count().sort_values(by='DOI').DOI

plot = topByCityCountry.plot.pie(figsize=(25,25), fontsize=20,autopct='%.2f%%')

#plt.title("Fig. 8 - Top 50 Countries Requesting Articles to the Sci-Hub", fontsize=50)
#plt.savefig('./../../charts and figures/'+ "Fig. 8 - Top 50 countries" + ".pdf")

# %%
statistics2017.loc[statistics2017.city == "تاديغوست",:].head()
# Out:
#                                DOI   IPID      city  country  \
# 722          10.1093/imamci/dnw015  20922  تاديغوست  Morocco
# 821      10.1007/s11538-016-0209-6  29983  تاديغوست  Morocco
# 937   10.1016/j.emcodo.2004.12.003  33026  تاديغوست  Morocco
# 1320     10.1016/j.cam.2013.08.014  43594  تاديغوست  Morocco
# 1554          10.1210/er.2007-0022  50608  تاديغوست  Morocco
#
#                      date is_oa        lat       lon  userID continent  \
# 722   2017-01-01 14:24:03     f  31.905128 -4.727753   30212    Africa
# 821   2017-01-01 15:39:34     t  31.905128 -4.727753   43396    Africa
# 937   2017-01-01 16:36:21     f  31.905128 -4.727753   47722    Africa
# 1320  2017-01-01 20:25:23     f  31.905128 -4.727753   61959    Africa
# 1554  2017-01-01 23:25:00     t  31.905128 -4.727753   71087    Africa
#
#       DOI_prefix
# 722      10.1093
# 821      10.1007
# 937      10.1016
# 1320     10.1016
# 1554     10.1210

# %%
statistics2017.loc[statistics2017.country == "Syria",:].head()
# Out:
#                                      DOI    IPID   city country  \
# 3927                 10.1093/ajae/aas031  121390    NaN   Syria
# 5616           10.1007/s00216-011-4670-7  163037  Hamah   Syria
# 7107          10.1109/dcoss.2011.5982177  194475    NaN   Syria
# 7286  10.1016/b978-0-08-100301-5.00015-1  204942  Hamah   Syria
# 7649          10.1108/ijopm-04-2012-0131  215545  Hamah   Syria
#
#                      date is_oa        lat        lon  userID continent  \
# 3927  2017-01-02 20:58:07     f  35.011398  37.056134  160607      Asia
# 5616  2017-01-03 11:54:07     f  35.140888  36.755199  230258      Asia
# 7107  2017-01-03 19:48:15     f  35.011398  37.056134  174596      Asia
# 7286  2017-01-03 21:02:14     f  35.140888  36.755199  174703      Asia
# 7649  2017-01-04 00:10:24     f  35.140888  36.755199  316724      Asia
#
#       DOI_prefix
# 3927     10.1093
# 5616     10.1007
# 7107     10.1109
# 7286     10.1016
# 7649     10.1108

# %%
statistics2017.loc[statistics2017.country == "Taiwan",:]
# Out:
#                                                        DOI      IPID city  \
# 191                              10.1017/s0144686x15001245      8307  中正區
# 227                             10.1016/j.eswa.2004.10.016      9270  鳳山區
# 237                             10.1016/j.jcps.2010.12.003      8964   中區
# 263                              10.1016/j.nrl.2016.10.007     10531  中正區
# 590                             10.1103/physrevd.94.101301     18695  鳳山區
# 666                           10.1016/j.chroma.2016.01.019     24219  信義鄉
# 731                              10.1080/14783360802227803     25508  中正區
# 752                              10.1108/14676370210434688     26021  中正區
# 753                           10.1021/acs.jnatprod.5b00810     27142  信義鄉
# 823                                 10.1002/jcp.1041160302     10131  信義鄉
# 870                                   10.1115/gt2010-23025     31200  鳳山區
# 887                              10.1109/mcom.2016.7588228     31795  中正區
# ...

# %%
statistics2017.loc[statistics2017.country == "Hong Kong",:]
# Out:
#                                                    DOI      IPID       city  \
# 404                   10.1016/j.biotechadv.2008.03.001      6143        NaN
# 409                          10.1007/s00299-003-0660-3      6143        NaN
# 420                         10.1016/j.chom.2015.04.004     16009        NaN
# 657                          10.1007/s00005-014-0326-6     23972        NaN
# 981                                 10.1039/c6nr05046h     33861        NaN
# 1089                           10.1021/acs.joc.6b00469     34971        NaN
# 1097        10.1016/j.jstrokecerebrovasdis.2016.10.007     37918  Hong Kong
# 1170                     10.1080/14786419.2016.1269101     39305        NaN
# 1515                        10.1016/j.msec.2009.01.009     12859        NaN
# 1812                     10.1016/s0140-6736(14)61698-6     61376        NaN
# 1917                         10.1016/j.jct.2016.04.010     64523         石崗
# ...

# %%
table1.plot.bar(subplots=True,figsize=(10,10))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x00000229903DB0B8>],
#       dtype=object)
