# %%
import pandas as pd
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
statistics2017 = pd.read_csv("./../../data/sample/2017.statistics.sample.with_missing_cities_continents.csv")
statistics2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500000 entries, 0 to 1499999
# Data columns (total 11 columns):
# DOI           1500000 non-null object
# IPID          1500000 non-null int64
# city          1394066 non-null object
# country       1468489 non-null object
# date          1500000 non-null object
# is_oa         1480851 non-null object
# lat           1386787 non-null float64
# lon           1386787 non-null float64
# userID        1500000 non-null int64
# continent     1467987 non-null object
# DOI_prefix    1500000 non-null float64
# dtypes: float64(3), int64(2), object(6)
# memory usage: 125.9+ MB

# %%
table1 = statistics2017.loc[statistics2017.continent == "Africa",("country","DOI")].groupby('country').count().sort_values(by='DOI',ascending = False).head(10)
table1 = table1.rename({"DOI": "Downloads"}, axis = "columns")
table1
# Out:
#               Downloads
# country
# Egypt             15249
# Algeria           14776
# Tunisia           14197
# Morocco           12046
# Nigeria            4076
# South Africa       3199
# Seychelles         1956
# Ethiopia           1574
# Ghana              1163
# Cameroon           1073

# %%
print (table1.to_latex())
# Out:
# \begin{tabular}{lr}
# \toprule
# {} &  Downloads \\
# country      &            \\
# \midrule
# Egypt        &      15249 \\
# Algeria      &      14776 \\
# Tunisia      &      14197 \\
# Morocco      &      12046 \\
# Nigeria      &       4076 \\
# South Africa &       3199 \\
# Seychelles   &       1956 \\
# Ethiopia     &       1574 \\
# Ghana        &       1163 \\
# Cameroon     &       1073 \\
# \bottomrule
# \end{tabular}

# %%
table2 = statistics2017.loc[statistics2017.continent == "Africa",("country","city","DOI")].groupby(['country','city']).count().sort_values(by='DOI',ascending = False).head(10)
table2 = table2.rename({"DOI": "Downloads"}, axis = "columns")
table2
# Out:
#                         Downloads
# country  city
# Egypt    مدينة نصر 1         7735
# Morocco  تاديغوست            5245
#          Casablanca          1654
# Algeria  Algiers             1639
# Tunisia  Tunis               1043
# Egypt    سيدى جابر            972
# Morocco  Fes                  953
# Algeria  عين أمقل             896
# Ethiopia Ezhana Welene        765
# Cameroon Mbam-et-Kim          748

# %%
print (table2.to_latex())
# Out:
# \begin{tabular}{llr}
# \toprule
#          &             &  Downloads \\
# country & city &            \\
# \midrule
# Egypt & مدينة نصر 1 &       7735 \\
# Morocco & تاديغوست &       5245 \\
#          & Casablanca &       1654 \\
# Algeria & Algiers &       1639 \\
# Tunisia & Tunis &       1043 \\
# Egypt & سيدى جابر &        972 \\
# Morocco & Fes &        953 \\
# Algeria & عين أمقل &        896 \\
# Ethiopia & Ezhana Welene &        765 \\
# Cameroon & Mbam-et-Kim &        748 \\
# \bottomrule
# \end{tabular}

# %%
table3 = statistics2017.loc[statistics2017.continent == "Africa",("country","DOI")].groupby('country').count().sort_values(by='DOI').head(10)
table3 = table3.rename({"DOI": "Downloads"}, axis = "columns")
table3
# Out:
#                        Downloads
# country
# Comoros                        1
# Eritrea                        1
# South Sudan                    1
# Chad                           2
# Guinea-Bissau                  4
# Mayotte                        5
# São Tomé and Príncipe          6
# Cape Verde                     7
# The Gambia                     7
# Swaziland                      8

# %%
#Establishing 'Top Countries' by downloads:

topByCityCountry = statistics2017.loc[statistics2017.continent == "Africa",:].groupby("country").count().sort_values(by='DOI').DOI.tail(15)

plot = topByCityCountry.plot.pie(figsize=(25,25), fontsize=30,autopct='%.2f%%')

#plt.title("Fig. 8 - Top 50 Countries Requesting Articles to the Sci-Hub", fontsize=50)
#plt.savefig('./../../charts and figures/'+ "Fig. 8 - Top 50 countries" + ".pdf")

# %%
statistics2017.loc[statistics2017.continent == "Africa",:].country.unique()
# Out:
# array(['Algeria', 'Morocco', 'Egypt', 'Tunisia', 'Nigeria', 'Sudan',
#        'Somalia', 'Cameroon', 'Mauritius', 'Ethiopia', 'Rwanda', 'Kenya',
#        'South Africa', 'Benin', 'Senegal', 'Tanzania', 'Madagascar',
#        'Zimbabwe', 'Ghana', 'Gabon', 'Reunion', 'Burkina Faso', 'Mali',
#        'Uganda', 'Republic of the Congo', 'Libya', 'Angola', 'Guinea',
#        'Niger', 'Democratic Republic of the Congo', 'Namibia',
#        "Côte d'Ivoire", 'Mauritania', 'Togo', 'Botswana', 'Malawi',
#        'The Gambia', 'Mozambique', 'Seychelles', 'Sierra Leone', 'Zambia',
#        'Cape Verde', 'Guinea-Bissau', 'Djibouti', 'Lesotho', 'Comoros',
#        'Mayotte', 'South Sudan', 'São Tomé and Príncipe', 'Swaziland',
#        'Chad', 'Burundi', 'Liberia', 'Eritrea'], dtype=object)

# %%
statistics2017.loc[statistics2017.city == "تاديغوست",:].head()
# Out:
#                                DOI   IPID      city  country  \
# 722          10.1093/imamci/dnw015  20922  تاديغوست  Morocco
# 821      10.1007/s11538-016-0209-6  29983  تاديغوست  Morocco
# 937   10.1016/j.emcodo.2004.12.003  33026  تاديغوست  Morocco
# 1320     10.1016/j.cam.2013.08.014  43594  تاديغوست  Morocco
# 1554          10.1210/er.2007-0022  50608  تاديغوست  Morocco
#
#                      date is_oa        lat       lon  userID continent  \
# 722   2017-01-01 14:24:03     f  31.905128 -4.727753   30212    Africa
# 821   2017-01-01 15:39:34     t  31.905128 -4.727753   43396    Africa
# 937   2017-01-01 16:36:21     f  31.905128 -4.727753   47722    Africa
# 1320  2017-01-01 20:25:23     f  31.905128 -4.727753   61959    Africa
# 1554  2017-01-01 23:25:00     t  31.905128 -4.727753   71087    Africa
#
#       DOI_prefix
# 722      10.1093
# 821      10.1007
# 937      10.1016
# 1320     10.1016
# 1554     10.1210

# %%
statistics2017.loc[statistics2017.country == "Morocco",:].head()
# Out:
#                               DOI  IPID         city  country  \
# 6   10.1016/s0048-7333(02)00068-9   665         Safi  Morocco
# 31     10.1016/j.ejor.2016.07.051  1589       Meknes  Morocco
# 34      10.1080/01496398308060291  1461  Béni Mellal  Morocco
# 71     10.1016/j.jns.2015.08.1314  3162        Rabat  Morocco
# 86   10.1016/j.neurol.2016.01.331  3162        Rabat  Morocco
#
#                    date is_oa        lat       lon  userID continent  \
# 6   2017-01-01 00:13:20     f  32.300815 -9.227203     765    Africa
# 31  2017-01-01 00:57:48     f  33.873016 -5.540730    1966    Africa
# 34  2017-01-01 01:00:52     f  32.342443 -6.375799    1808    Africa
# 71  2017-01-01 02:00:41     f  33.971590 -6.849813    4130    Africa
# 86  2017-01-01 02:29:23     f  33.971590 -6.849813    5549    Africa
#
#     DOI_prefix
# 6      10.1016
# 31     10.1016
# 34     10.1080
# 71     10.1016
# 86     10.1016

# %%
statistics2017.loc[statistics2017.country == "Ethiopia",:].head()
# Out:
#                                           DOI    IPID           city  \
# 551               10.4049/jimmunol.172.3.1637     377  Ezhana Welene
# 1460         10.2165/00003088-200847050-00001     377  Ezhana Welene
# 2956            10.1016/s0038-0717(01)00235-8   90927    Addis Ababa
# 3347  10.1061/(asce)0733-947x(2001)127:2(105)  103236    Addis Ababa
# 3993                   10.1186/2041-7136-3-12   26794    Addis Ababa
#
#        country                 date is_oa       lat        lon  userID  \
# 551   Ethiopia  2017-01-01 12:09:29     t  8.182437  38.063146   22825
# 1460  Ethiopia  2017-01-01 22:04:37     f  8.182437  38.063146   62089
# 2956  Ethiopia  2017-01-02 14:42:44     f  8.980069  38.798932  132894
# 3347  Ethiopia  2017-01-02 17:08:45     f  8.980069  38.798932  147441
# 3993  Ethiopia  2017-01-02 21:37:59     t  8.980069  38.798932   76050
#
#      continent  DOI_prefix
# 551     Africa     10.4049
# 1460    Africa     10.2165
# 2956    Africa     10.1016
# ...

# %%
statistics2017.loc[statistics2017.country == "Democratic Republic of the Congo",:].head()
# Out:
#                                   DOI     IPID        city  \
# 15138    10.1016/j.canrad.2005.09.017   369902      Basoko
# 27131    10.1016/0378-8741(91)90104-l   608894  Lubumbashi
# 82328    10.1016/j.toxlet.2004.04.027  1178972      Basoko
# 101397  10.1016/s0047-2727(99)00022-5   524202      Basoko
# 110937  10.1016/s1957-2557(12)70356-5  2041359      Basoko
#
#                                  country                 date is_oa  \
# 15138   Democratic Republic of the Congo  2017-01-06 06:46:23     f
# 27131   Democratic Republic of the Congo  2017-01-10 09:41:22     f
# 82328   Democratic Republic of the Congo  2017-01-28 01:00:39     f
# 101397  Democratic Republic of the Congo  2017-02-03 13:26:22     f
# 110937  Democratic Republic of the Congo  2017-02-06 16:29:58     f
#
#               lat        lon   userID continent  DOI_prefix
# 15138    0.545546  24.904221   321519    Africa     10.1016
# 27131  -11.687603  27.502617   855660    Africa     10.1016
# ...

# %%
statistics2017.loc[statistics2017.country == "Tunisia",:].head()
# Out:
#                                 DOI  IPID city  country                 date  \
# 51   10.1016/j.ceramint.2011.08.044  2127  NaN  Tunisia  2017-01-01 01:17:34
# 101       10.1108/00022660510585992  3431  NaN  Tunisia  2017-01-01 03:07:50
# 137     10.1109/icinfa.2014.6932731  2888  NaN  Tunisia  2017-01-01 04:42:05
# 396     10.1016/j.agwat.2010.08.018  6190  NaN  Tunisia  2017-01-01 10:04:48
# 401     10.1016/j.agwat.2016.02.023  6190  NaN  Tunisia  2017-01-01 10:09:34
#
#     is_oa        lat       lon  userID continent  DOI_prefix
# 51      f  33.776126  8.861088    2682    Africa     10.1016
# 101     f  33.776126  8.861088    4485    Africa     10.1108
# 137     f  33.776126  8.861088    3742    Africa     10.1109
# 396     f  33.776126  8.861088    8396    Africa     10.1016
# 401     t  33.776126  8.861088    8396    Africa     10.1016

# %%
statistics2017.loc[statistics2017.country == "Algeria",:].head()
# Out:
#                                    DOI  IPID      city  country  \
# 5                    10.1021/jf504119s   619       NaN  Algeria
# 22  10.1016/b978-2-294-74506-5.09991-4  1522       NaN  Algeria
# 29         10.1016/j.cirpj.2013.07.005  1768       NaN  Algeria
# 40                 10.2514/6.2002-3804  2319       NaN  Algeria
# 55           10.1007/978-2-8178-0115-5  2786  عين أمقل  Algeria
#
#                    date is_oa        lat       lon  userID continent  \
# 5   2017-01-01 00:10:18     f        NaN       NaN     711    Africa
# 22  2017-01-01 00:39:51     f        NaN       NaN    1883    Africa
# 29  2017-01-01 00:52:50     f        NaN       NaN    2194    Africa
# 40  2017-01-01 01:04:06     f        NaN       NaN    2937    Africa
# 55  2017-01-01 01:23:08     f  24.098289  3.743509    3607    Africa
#
#     DOI_prefix
# 5      10.1021
# 22     10.1016
# 29     10.1016
# 40     10.2514
# 55     10.1007

# %%
statistics2017.loc[statistics2017.country == "Central African Republic",:].head()
# Out:
# Empty DataFrame
# Columns: [DOI, IPID, city, country, date, is_oa, lat, lon, userID, continent, DOI_prefix]
# Index: []

# %%
table2.plot.pie(subplots=True,figsize=(10,10))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001E1826A4F98>],
#       dtype=object)
