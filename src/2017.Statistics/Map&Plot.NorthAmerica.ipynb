# %% [markdown]
# ## ANALYSIS

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from collections import Counter

# %% [markdown]
# ## Import DataFrame

# %%
statistics2017 = pd.read_csv("./../../data/sample/2017.statistics.sample.with_missing_cities_continents.csv")

# %%
country_list = ["Mexico","Cuba","Dominican Republic","Haiti","Guadeloupe","Martinique", "Saint-Barthélemy",
                "Puerto Rico","Belize","Costa Rica","El Salvador","Guatemala","Honduras","Nicaragua","Panama"]

# %%
list_1 = [statistics2017.loc[statistics2017.continent == "North America"].country.unique()]
list_2 = country_list
NA_list = np.setdiff1d(list_1,list_2)

# %%
NA = statistics2017.loc[statistics2017.country == "United States",:]
for i in NA_list:
    NA2 = statistics2017.loc[statistics2017.country == i,:]
    NA = NA.append(NA2)

# %%
NA.head()
# Out:
#                                DOI  IPID           city        country  \
# 18               10.1021/es9809760  1228         Potwin  United States
# 41  10.1002/14651858.cd008320.pub3  1774  San Francisco  United States
# 45       10.1109/jssc.2014.2338873    55      Claremont  United States
# 67                10.2307/42986762  3412      Baltimore  United States
# 69           10.1056/nejmoa1506597   163         Dallas  United States
#
#                    date is_oa        lat         lon  userID      continent  \
# 18  2017-01-01 00:31:54     f  37.938906  -97.019756    1490  North America
# 41  2017-01-01 01:08:08     f  37.774929 -122.419415    3070  North America
# 45  2017-01-01 01:13:49     f  34.096676 -117.719779      58  North America
# 67  2017-01-01 01:51:36   NaN  39.290385  -76.612189    4461  North America
# 69  2017-01-01 01:55:56     t  32.776664  -96.796988     176  North America
#
#     DOI_prefix
# 18     10.1021
# 41     10.1002
# 45     10.1109
# 67     10.2307
# 69     10.1056

# %%
def show_cart():
    fig = plt.figure(figsize=(20,20))
    ax = plt.axes(projection=ccrs.PlateCarree())
    ax.coastlines( color='black', linewidth=1)
    ax.add_feature(cfeature.BORDERS, linestyle=':', linewidth=0.5 )

def scatter_points(lat, lon):
    c = Counter(zip(lon,lat))
    area = [0.1 * c[(lonlon,latlat)]*2 for lonlon,latlat in zip(lon,lat)]
    plt.scatter(lon, lat, color="darkred" ,marker='.', s=area)

def plotmap(df, title):
    for i in df.drop_duplicates():
        lat=df.lat
        lon=df.lon
    show_cart()
    scatter_points(lat, lon)
    plt.show()

# %%
plotmap(NA, "asd")
