# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Import DataFrame

# %%
statistics2017 = pd.read_csv("./../../data/cities-population-downloads.csv")

# %%
plot = statistics2017.loc[statistics2017.country == "Brazil",:].sort_values(by="Downloads",ascending = False).head(25)

# %%
plot
# Out:
#       city_pop country                 city  Downloads  1000hb_city
# 4     136456.0  Brazil            São Paulo      15949   116.880167
# 29   6023742.0  Brazil       Rio de Janeiro       5267     0.874373
# 52   1372763.0  Brazil         Porto Alegre       3049     2.221068
# 56   2373255.0  Brazil       Belo Horizonte       2860     1.205096
# 69   2207812.0  Brazil             Brasília       2170     0.982874
# 92   2711903.0  Brazil             Salvador       1606     0.592204
# 99     11480.0  Brazil         Luís Correia       1475   128.484321
# 128  1031573.0  Brazil             Campinas       1046     1.013985
# 133  1171209.0  Brazil              Goiânia       1026     0.876018
# 146   205039.0  Brazil           São Carlos        963     4.696667
# 188   320680.0  Brazil              Pelotas        734     2.288886
# 194   763057.0  Brazil                Natal        713     0.934399
# 200   490184.0  Brazil              Aracaju        683     1.393354
# ...

# %%
plt.subplots(figsize=(15,10))
#plt.xticks(rotation=90)

plot = sns.barplot('1000hb_city', "city", data= plot)


plot.set_ylabel("Downloads p/1000 hab.", fontsize=12)
plot.set_xlabel(" ", fontsize=20)
sns.set_style('darkgrid')
#plt.title("Fig. 8 - Top 50 Countries Requesting Articles to the Sci-Hub", fontsize=15)
#plt.savefig('./../../charts and figures/'+ "Fig. 8 - Top 50 countries" + ".pdf")

# %%
statistics2017.loc[statistics2017.city == "Luís Correia",:]
# Out:
#     city_pop country          city  Downloads  1000hb_city
# 99   11480.0  Brazil  Luís Correia       1475   128.484321
