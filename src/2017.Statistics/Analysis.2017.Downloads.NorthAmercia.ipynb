# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Import DataFrame

# %%
statistics2017 = pd.read_csv("./../../data/sample/2017.statistics.sample.with_missing_cities_continents.csv")
statistics2017 = statistics2017.rename({"DOI": "Downloads"}, axis = "columns")
statistics2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500000 entries, 0 to 1499999
# Data columns (total 11 columns):
# Downloads     1500000 non-null object
# IPID          1500000 non-null int64
# city          1394066 non-null object
# country       1468489 non-null object
# date          1500000 non-null object
# is_oa         1480851 non-null object
# lat           1386787 non-null float64
# lon           1386787 non-null float64
# userID        1500000 non-null int64
# continent     1467987 non-null object
# DOI_prefix    1500000 non-null float64
# dtypes: float64(3), int64(2), object(6)
# memory usage: 125.9+ MB

# %%
country_list = ["Mexico","Cuba","Dominican Republic","Haiti","Guadeloupe","Martinique", "Saint-Barthélemy",
                "Puerto Rico","Belize","Costa Rica","El Salvador","Guatemala","Honduras","Nicaragua","Panama"]

# %%
list_1 = [statistics2017.loc[statistics2017.continent == "North America"].country.unique()]
list_2 = country_list
NA_list = np.setdiff1d(list_1,list_2)

# %%
NA = statistics2017.loc[statistics2017.country == "United States",:]
for i in NA_list:
    NA2 = statistics2017.loc[statistics2017.country == i,:]
    NA = NA.append(NA2)

# %%
NA = NA.drop_duplicates()

# %%
plot1 = NA.groupby("country").count().sort_values("date", ascending=False).head(10).Downloads

# %%
table1 = NA.loc[:,("country","city","Downloads")].groupby(['country']).count().sort_values(by='Downloads',ascending = False).head(15)
table1 = table1.loc[:,"Downloads"]
print(table1.to_latex())
# Out:
# \begin{tabular}{lr}
# \toprule
# {} &  Downloads \\
# country                &            \\
# \midrule
# United States          &     110440 \\
# Canada                 &      25237 \\
# Jamaica                &        124 \\
# Trinidad and Tobago    &         96 \\
# British Virgin Islands &         54 \\
# Barbados               &         44 \\
# Saint Kitts and Nevis  &         41 \\
# The Bahamas            &         16 \\
# Antigua and Barbuda    &          9 \\
# Grenada                &          9 \\
# Dominica               &          3 \\
# Saint Lucia            &          3 \\
# Cayman Islands         &          3 \\
# Greenland              &          2 \\
# Sint Maarten           &          2 \\
# \bottomrule
# \end{tabular}

# %%
table2 = NA.loc[:,("country","city","Downloads")].groupby(['country','city']).count().sort_values(by='Downloads',ascending = False).head(15)
table2
# Out:
#                            Downloads
# country       city
# Canada        Toronto          13563
# United States Los Angeles       8962
#               Chicago           6735
#               San Jose          5427
#               Wilmington        5403
#               Buffalo           5038
#               Potwin            4643
#               Ann Arbor         3739
#               New York          3297
#               Galloway          2826
#               Fremont           2642
#               Manassas          2591
#               Matawan           2325
#               Phoenix           2279
#               Atlanta           2178

# %%
print (table2.to_latex())
# Out:
# \begin{tabular}{llr}
# \toprule
#               &         &  Downloads \\
# country & city &            \\
# \midrule
# Canada & Toronto &      13563 \\
# United States & Los Angeles &       8962 \\
#               & Chicago &       6735 \\
#               & San Jose &       5427 \\
#               & Wilmington &       5403 \\
#               & Buffalo &       5038 \\
#               & Potwin &       4643 \\
#               & Ann Arbor &       3739 \\
#               & New York &       3297 \\
#               & Galloway &       2826 \\
#               & Fremont &       2642 \\
#               & Manassas &       2591 \\
#               & Matawan &       2325 \\
#               & Phoenix &       2279 \\
#               & Atlanta &       2178 \\
# \bottomrule
# \end{tabular}

# %%
NA.groupby("country").count().sort_values(by="Downloads", ascending=False).head(10)
# Out:
#                         Downloads    IPID    city    date   is_oa     lat  \
# country
# United States              110440  110440  109912  110440  109287  109912
# Canada                      25237   25237   25236   25237   24998   25237
# Jamaica                       124     124     124     124     124     124
# Trinidad and Tobago            96      96      78      96      95      67
# British Virgin Islands         54      54      46      54      54      46
# Barbados                       44      44      44      44      41      44
# Saint Kitts and Nevis          41      41      41      41      41      41
# The Bahamas                    16      16      16      16      15      16
# Antigua and Barbuda             9       9       9       9       8       9
# Grenada                         9       9       9       9       9       9
#
#                            lon  userID  continent  DOI_prefix
# country
# United States           109912  110440     110440      110440
# Canada                   25237   25237      25237       25237
# Jamaica                    124     124        124         124
# Trinidad and Tobago         67      96         96          96
# British Virgin Islands      46      54         54          54
# Barbados                    44      44         44          44
# Saint Kitts and Nevis       41      41         41          41
# The Bahamas                 16      16         16          16
# Antigua and Barbuda          9       9          9           9
# Grenada                      9       9          9           9
