# %% [markdown]
# ## ANALYSIS

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from collections import Counter

# %% [markdown]
# ## Import DataFrame

# %%
statistics2017 = pd.read_csv("./../../data/sample/2017.statistics.sample.with_missing_cities_continents.csv")

# %%
statistics2017.head()
# Out:
#                                 DOI  IPID           city country  \
# 0  10.1111/j.1755-6724.2011.00377.x   177  Guangzhou Shi   China
# 1  10.1111/j.1755-6724.2011.00378.x   177  Guangzhou Shi   China
# 2                  10.2514/1.b34382    57         Milano   Italy
# 3           10.1073/pnas.0902793106    19            NaN     NaN
# 4      10.1007/978-3-540-39923-0_12   310     Concepción   Chile
#
#                   date is_oa        lat         lon  userID      continent  \
# 0  2017-01-01 00:02:06     f  23.129110  113.264385     191           Asia
# 1  2017-01-01 00:03:29     f  23.129110  113.264385     191           Asia
# 2  2017-01-01 00:06:12     f  45.465422    9.185924      60         Europe
# 3  2017-01-01 00:08:49     t        NaN         NaN     637            NaN
# 4  2017-01-01 00:08:51     f -36.820135  -73.044390     340  South America
#
#    DOI_prefix
# 0     10.1111
# 1     10.1111
# 2     10.2514
# 3     10.1073
# 4     10.1007

# %%
country_list = ["Mexico","Cuba","Dominican Republic","Haiti","Guadeloupe","Martinique", "Saint-Barthélemy",
                "Puerto Rico","Belize","Costa Rica","El Salvador","Guatemala","Honduras","Nicaragua","Panama"]

# %%
    LA = statistics2017.loc[statistics2017.continent == "South America",:]
    for i in country_list:
        df2 = statistics2017.loc[statistics2017.country == i,:]
        LA = LA.append(df2)

# %%
LA.country.unique()
# Out:
# array(['Chile', 'Brazil', 'Colombia', 'Peru', 'Ecuador', 'Argentina',
#        'Uruguay', 'Venezuela', 'Bolivia', 'Paraguay', 'Suriname',
#        'Guyana', 'Curaçao', 'Aruba', 'Falkland Islands',
#        'Caribbean Netherlands', 'Mexico', 'Cuba', 'Dominican Republic',
#        'Haiti', 'Guadeloupe', 'Martinique', 'Puerto Rico', 'Belize',
#        'Costa Rica', 'El Salvador', 'Guatemala', 'Honduras', 'Nicaragua',
#        'Panama'], dtype=object)

# %%
LA.head()
# Out:
#                                    DOI  IPID                       city  \
# 4         10.1007/978-3-540-39923-0_12   310                 Concepción
# 16                     10.1038/nrg3240   818  Balneário Arroio do Silva
# 24                  10.1039/c0an00609b   859                  São Paulo
# 32        10.1016/0165-1781(81)90018-4  1487                   Medellín
# 39  10.1111/j.1095-8312.1996.tb01468.x   197                      Rímac
#
#      country                 date is_oa        lat        lon  userID  \
# 4      Chile  2017-01-01 00:08:51     f -36.820135 -73.044390     340
# 16    Brazil  2017-01-01 00:29:48     t -29.019519 -49.477112    1298
# 24    Brazil  2017-01-01 00:42:26     f -23.550520 -46.633309     998
# 32  Colombia  2017-01-01 00:57:53     f   6.253041 -75.564574    1840
# 39      Peru  2017-01-01 01:02:36     f -12.027121 -77.036238     215
#
#         continent  DOI_prefix
# 4   South America     10.1007
# 16  South America     10.1038
# 24  South America     10.1039
# 32  South America     10.1016
# 39  South America     10.1111

# %%
def show_cart():
    fig = plt.figure(figsize=(20,20))
    ax = plt.axes(projection=ccrs.PlateCarree())
    ax.coastlines( color='black', linewidth=1)
    ax.add_feature(cfeature.BORDERS, linestyle=':', linewidth=0.5 )

def scatter_points(lat, lon):
    c = Counter(zip(lon,lat))
    area = [0.1 * c[(lonlon,latlat)]*2 for lonlon,latlat in zip(lon,lat)]
    plt.scatter(lon, lat, color="darkred" ,marker='.', s=area)

def plotmap(df, title):
    for i in df.drop_duplicates():
        lat=df.lat
        lon=df.lon
    show_cart()
    scatter_points(lat, lon)
    plt.show()

# %%
plotmap(LA, "ASD")
