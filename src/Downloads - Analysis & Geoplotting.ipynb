# %% [markdown]
# ## ANALYSIS

# %%
import pandas as pd
import numpy as np
import cartopy.crs as ccrs
import matplotlib.pyplot as plt

# %%
statistics2017 = pd.read_table("./../../data/sample/statistics2017_sample", header=None)
#give columns names
statistics2017.columns = ["date", "DOI", "IPID", "userID", "country", "city", "lat", "lon"]

# %%
#remove parenthsis and special characters
statistics2017["country"] = statistics2017["country"].str.replace(r" *\(.*\)", "")

# %%
#Giving coontinents to countries:

countries_continent = pd.read_csv('./../../data/Countries-Continents.csv')

# %%
statistics2017 = pd.merge(statistics2017, countries_continent,
         left_on = "country", right_on = "Country", how = "left")
statistics2017 = statistics2017.drop(columns="Country")
statistics2017 = statistics2017.rename({"Continent": "continent"}, axis = "columns")

statistics2017.head()
# Out:
#                   date                                 DOI     IPID   userID  \
# 0  2017-03-06 09:00:15       10.1016/S2212-5671(15)00804-7  3492310  5080056
# 1  2017-01-30 02:10:54        10.1016/0014-4835(92)90190-4  1635190  2417619
# 2  2017-01-05 19:06:37  10.1016/b978-0-12-394813-7.00002-x   342740     2317
# 3  2017-01-16 20:01:49               10.1089/tmj.2015.0135   580956   881730
# 4  2017-01-04 15:09:12                  10.1007/BF00821580   255424   389403
#
#           country            city        lat         lon      continent
# 0       Indonesia             NaN  -6.903485  107.617093           Asia
# 1  United Kingdom       Kettering  52.396322   -0.730249         Europe
# 2       Indonesia             NaN  -6.178905  106.826687           Asia
# 3          Brazil  Rio de Janeiro -22.906847  -43.172897  South America
# 4         Ukraine           L'viv  49.839683   24.029717         Europe

# %%
#Establishing 'Top Countries' by downloads:

topByCityCountry = statistics2017.groupby("country").count().sort_values("date", ascending=False).head(50).date

topByCityCountry.plot.bar(figsize=(40,10), fontsize=20)

# %%
#Gettting to the top cities in the top countries:
a = []
for i in pd.Series(topByCityCountry).index:
    a.append(i)
#creating a temporay list
    tmp = []

for i in a:    
    b = statistics2017.loc[statistics2017.country == i,('city','continent')].groupby("city").count().sort_values(by="continent", ascending=False).head(7)
    print(i.upper(),b)
    tmp.append(b.index.values.tolist())
# Out:
# CHINA                continent
# city
# Beijing              143
# Shanghai             137
# Dingxi Shi            99
# Guangzhou Shi         55
# Nanjing Shi           54
# Wuhan Shi             41
# Hangzhou Shi          34
# INDIA                continent
# city
# Gugal Pimpari         87
# New Delhi             45
# Chennai               43
# Hyderabad             37
# Bengaluru             35
# Gurgaon               33
# Mumbai                30
# UNITED STATES              continent
# city
# Los Angeles         49
# Chicago             40
# Wilmington          28
# San Jose            24
# Potwin              22
# Fremont             21
# Buffalo             19
# BRAZIL                 continent
# city
# São Paulo              72
# Rio de Janeiro         20
# Porto Alegre           12
# Brasília               12
# Curitiba               11
# Campinas                9
# Belo Horizonte          9
# IRAN           continent
# city
# Tehran          159
# Tiran            32
# Isfahan          15
# Tabriz            9
# Yazd              4
# Hamedan           3
# Sanandaj          3
# INDONESIA Empty DataFrame
# Columns: [continent]
# Index: []
# RUSSIA                   continent
# city
# Moskva                   74
# Sankt-Peterburg          15
# Kazan                     6
# Perm                      4
# Nizhnij Novgorod          3
# Yaroslavl'                3
# Voronez                   3
# FRANCE               continent
# city
# Paris                75
# Montpellier           4
# Strasbourg            4
# Villeurbanne          3
# Nice                  3
# Toulouse              3
# Marseille             2
# MEXICO                    continent
# city
# Ejido del Centro          23
# Ciudad de México          16
# Guadalajara               12
# Ciudad Cuauhtémoc         11
# Veracruz                   8
# Monterrey                  7
# Ciudad Juárez              6
# UNITED KINGDOM                      continent
# city
# London                      79
# Gosport                      4
# Newcastle upon Tyne          4
# Boars Hill                   3
# Plymouth                     3
# Leeds                        2
# Belfast                      2
# GERMANY                    continent
# city
# Haina (Kloster)           32
# Berlin                    13
# München                   11
# Frankfurt am Main          8
# Essen                      8
# Stuttgart                  6
# Münster                    4
# SOUTH KOREA            continent
# city
# Seoul            100
# Suncheon           3
# Suwon              3
# Busan              2
# Daejeon            2
# Incheon            2
# Yongin-si          2
# SPAIN                             continent
# city
# Madrid                             40
# Barcelona                          17
# València                           14
# Sevilla                             5
# Las Palmas de Gran Canaria          3
# Bilbo                               3
# Valladolid                          2
# ITALY                      continent
# city
# Roma                        14
# Milano                       7
# Napoli                       6
# Padova                       4
# Udine                        3
# Genova                       3
# Baselga del Bondone          3
# MALAYSIA                continent
# city
# Kuala Lumpur          20
# Balingian             18
# Puchong                9
# Johor Bahru            6
# Shah Alam              4
# Jitra                  4
# Petaling Jaya          3
# CANADA           continent
# city
# Toronto          51
# Montreal         10
# Montréal          6
# Waterloo          2
# Burnaby           2
# Edmonton          2
# Ottawa            2
# NETHERLANDS               continent
# city
# Amsterdam            64
# Alblasserdam          6
# Utrecht               6
# Groningen             3
# Tilburg               2
# Zwijndrecht           2
# Arnhem                1
# COLOMBIA              continent
# city
# Bogotá              45
# Medellín            21
# Cali                 5
# Bucaramanga          4
# Pereira              2
# Manizales            1
# Neiva                1
# PAKISTAN             continent
# city
# Lahore             19
# Karachi            10
# Faisalabad          7
# Islamabad           5
# Rawalpindi          4
# Peshawar            2
# Wān                 2
# TURKEY Empty DataFrame
# Columns: [continent]
# Index: []
# TAIWAN Empty DataFrame
# Columns: [continent]
# Index: []
# HONG KONG Empty DataFrame
# Columns: [continent]
# Index: []
# PORTUGAL           continent
# city
# Lisboa           31
# Porto             9
# Braga             5
# Parede            2
# Aveiro            2
# Caparica          2
# Lagos             2
# ALGERIA              continent
# city
# Algiers              7
# Oran                 7
# Chlef                6
# Annaba               2
# Batna                1
# Béchar               1
# Constantine          1
# CHILE               continent
# city
# Santiago             41
# Concepción            5
# Viña del Mar          4
# Temuco                3
# Antofagasta           1
# Chiguayante           1
# La Serena             1
# SINGAPORE            continent
# city
# Singapore         62
# ARGENTINA               continent
# city
# Buenos Aires         39
# Córdoba               3
# Alta Gracia           1
# Campana               1
# Claypole              1
# Federal               1
# Ituzaingó             1
# JAPAN                 continent
# city
# Shinjuku-ku            20
# Chiyoda-ku             11
# Ōsaka-shi               4
# Ōta-ku                  3
# Yokohama-shi            2
# Utsunomiya-shi          2
# Sagamihara-shi          2
# ROMANIA                   continent
# city
# Craiova                  21
# Târgu Gânguleşti          9
# București                 8
# Cluj-Napoca               4
# Timișoara                 3
# Aroneanu                  1
# Chitid                    1
# GREECE               continent
# city
# Athina               36
# Thessaloniki          7
# Patra                 4
# Iraklio               3
# Ioannina              2
# Chania                1
# Larisa                1
# POLAND                     continent
# city
# Warszawa                   13
# Wrocław                     6
# Warząchewka Polska          5
# Poznań                      4
# Gdańsk                      4
# Zielona Góra                3
# Kraków                      2
# EGYPT Empty DataFrame
# Columns: [continent]
# Index: []
# TUNISIA          continent
# city
# Tunis            4
# Manouba          2
# Gafsa            1
# Sfax             1
# PHILIPPINES              continent
# city
# Manila              20
# Quezon City          6
# Makati               3
# Pasig                2
# Marikina             2
# Mandaluyong          2
# Antipolo             2
# PERU                                   continent
# city
# Distrito de Lima                         35
# Rímac                                     5
# Lima                                      3
# Callao                                    1
# Cercado de Lima                           1
# Distrito de Víctor Larco Herrera          1
# UKRAINE            continent
# city
# Kyiv              22
# Kharkiv            8
# L'viv              2
# Alchevs'k          1
# Chernihiv          1
# Odesa              1
# Sumy               1
# VIETNAM                   continent
# city
# Hanoi                    22
# Ho Chi Minh City          9
# Da Nang                   1
# AUSTRALIA                     continent
# city
# Melbourne                   3
# Alexandria                  2
# Clayton                     2
# Hornsby                     2
# Blackstone Heights          1
# Leichhardt                  1
# Sydney                      1
# MOROCCO              continent
# city
# Béni Mellal          3
# Casablanca           3
# Oujda                3
# Rabat                2
# Sidi Kacem           2
# Agadir               1
# Fes                  1
# ECUADOR            continent
# city
# Quito             20
# Guayaquil          6
# Ambato             3
# Cuenca             3
# SWITZERLAND                continent
# city
# Romoos                14
# Zürich                 3
# Bern                   2
# Blonay                 2
# Baar                   1
# Basel                  1
# Collina d'Oro          1
# BELGIUM            continent
# city
# Antwerpen          5
# Bruxelles          4
# Leuven             4
# Liège              2
# Aarschot           1
# Brugge             1
# Gent               1
# SWEDEN             continent
# city
# Stockholm          15
# Sundbyberg          3
# Örebro              2
# Lund                1
# Solna               1
# Umeå                1
# THAILAND                    continent
# city
# Bangkok                   13
# Chiang Mai                 1
# Muang Pattaya              1
# Songkhla                   1
# Tambon Bang Prok           1
# Tambon Takuk Nuea          1
# Tambon Wichit              1
# HUNGARY              continent
# city
# Budapest            14
# Szeged               2
# Göd                  1
# Nyíregyháza          1
# Solymár              1
# Szombathely          1
# Veszprém             1
# CZECH REPUBLIC                 continent
# city
# Prague                 10
# Brno                    4
# Blansko                 1
# Olomouc                 1
# Pilsen                  1
# Třinec                  1
# Ústí nad Labem          1
# SOUTH AFRICA               continent
# city
# Pretoria              4
# Durban                3
# Bloemfontein          1
# Cape Town             1
# Centurion             1
# George                1
# Johannesburg          1
# SLOVENIA                continent
# city
# Ljubljana              8
# Gabrovka               5
# Murska Sobota          1
# Nova Gorica            1
# Ptuj                   1
# Škofja Loka            1
# CROATIA                   continent
# city
# Donji Čehi                6
# Zagreb                    5
# Gornje Primišlje          3
# Adžamovci                 1
# Jesenice                  1
# Kamen                     1
# AUSTRIA                     continent
# city
# Wien                       10
# Edelsbach bei Graz          2
# Baden                       1
# Innsbruck                   1
# Salzburg                    1

# %%
for sublist in tmp:
    for item in sublist:
        top_cities.append(item)

# %%
#statistics2017.set_index("city")
#statistics2017.loc[top_cities,("city","lat", "lon")]
top_cities
# Out:
# ['Beijing',
#  'Shanghai',
#  'Dingxi Shi',
#  'Guangzhou Shi',
#  'Nanjing Shi',
#  'Wuhan Shi',
#  'Hangzhou Shi',
#  'Gugal Pimpari',
#  'New Delhi',
#  'Chennai',
#  'Hyderabad',
#  'Bengaluru',
#  'Gurgaon',
#  'Mumbai',
#  'Los Angeles',
#  'Chicago',
#  'Wilmington',
#  'San Jose',
#  'Potwin',
#  'Fremont',
#  'Buffalo',
#  'São Paulo',
#  'Rio de Janeiro',
#  'Porto Alegre',
#  'Brasília',
#  'Curitiba',
#  'Campinas',
#  'Belo Horizonte',
#  'Tehran',
#  'Tiran',
#  'Isfahan',
#  'Tabriz',
#  'Yazd',
#  'Hamedan',
#  'Sanandaj',
#  'Moskva',
#  'Sankt-Peterburg',
#  'Kazan',
#  'Perm',
#  'Nizhnij Novgorod',
#  "Yaroslavl'",
#  'Voronez',
#  'Paris',
#  'Montpellier',
#  'Strasbourg',
#  'Villeurbanne',
#  'Nice',
#  'Toulouse',
#  'Marseille',
#  'Ejido del Centro',
#  'Ciudad de México',
#  'Guadalajara',
#  'Ciudad Cuauhtémoc',
#  'Veracruz',
#  'Monterrey',
#  'Ciudad Juárez',
#  'London',
#  'Gosport',
#  'Newcastle upon Tyne',
#  'Boars Hill',
#  'Plymouth',
#  'Leeds',
#  'Belfast',
#  'Haina (Kloster)',
#  'Berlin',
#  'München',
#  'Frankfurt am Main',
#  'Essen',
#  'Stuttgart',
#  'Münster',
#  'Seoul',
#  'Suncheon',
#  'Suwon',
#  'Busan',
#  'Daejeon',
#  'Incheon',
#  'Yongin-si',
#  'Madrid',
#  'Barcelona',
#  'València',
#  'Sevilla',
#  'Las Palmas de Gran Canaria',
#  'Bilbo',
#  'Valladolid',
#  'Roma',
#  'Milano',
#  'Napoli',
#  'Padova',
#  'Udine',
#  'Genova',
#  'Baselga del Bondone',
#  'Kuala Lumpur',
#  'Balingian',
#  'Puchong',
#  'Johor Bahru',
#  'Shah Alam',
#  'Jitra',
#  'Petaling Jaya',
#  'Toronto',
#  'Montreal',
#  'Montréal',
#  'Waterloo',
#  'Burnaby',
#  'Edmonton',
#  'Ottawa',
#  'Amsterdam',
#  'Alblasserdam',
#  'Utrecht',
#  'Groningen',
#  'Tilburg',
#  'Zwijndrecht',
#  'Arnhem',
#  'Bogotá',
#  'Medellín',
#  'Cali',
#  'Bucaramanga',
#  'Pereira',
#  'Manizales',
#  'Neiva',
#  'Lahore',
#  'Karachi',
#  'Faisalabad',
#  'Islamabad',
#  'Rawalpindi',
#  'Peshawar',
#  'Wān',
#  'Lisboa',
#  'Porto',
#  'Braga',
#  'Parede',
#  'Aveiro',
#  'Caparica',
#  'Lagos',
#  'Algiers',
#  'Oran',
#  'Chlef',
#  'Annaba',
#  'Batna',
#  'Béchar',
#  'Constantine',
#  'Santiago',
#  'Concepción',
#  'Viña del Mar',
#  'Temuco',
#  'Antofagasta',
#  'Chiguayante',
#  'La Serena',
#  'Singapore',
#  'Buenos Aires',
#  'Córdoba',
#  'Alta Gracia',
#  'Campana',
#  'Claypole',
#  'Federal',
#  'Ituzaingó',
#  'Shinjuku-ku',
#  'Chiyoda-ku',
#  'Ōsaka-shi',
#  'Ōta-ku',
#  'Yokohama-shi',
#  'Utsunomiya-shi',
#  'Sagamihara-shi',
#  'Craiova',
#  'Târgu Gânguleşti',
#  'București',
#  'Cluj-Napoca',
#  'Timișoara',
#  'Aroneanu',
#  'Chitid',
#  'Athina',
#  'Thessaloniki',
#  'Patra',
#  'Iraklio',
#  'Ioannina',
#  'Chania',
#  'Larisa',
#  'Warszawa',
#  'Wrocław',
#  'Warząchewka Polska',
#  'Poznań',
#  'Gdańsk',
#  'Zielona Góra',
#  'Kraków',
#  'Tunis',
#  'Manouba',
#  'Gafsa',
#  'Sfax',
#  'Manila',
#  'Quezon City',
#  'Makati',
#  'Pasig',
#  'Marikina',
#  'Mandaluyong',
#  'Antipolo',
#  'Distrito de Lima',
#  'Rímac',
#  'Lima',
#  'Callao',
#  'Cercado de Lima',
#  'Distrito de Víctor Larco Herrera',
#  'Kyiv',
#  'Kharkiv',
#  "L'viv",
#  "Alchevs'k",
#  'Chernihiv',
#  'Odesa',
#  'Sumy',
#  'Hanoi',
#  'Ho Chi Minh City',
#  'Da Nang',
#  'Melbourne',
#  'Alexandria',
#  'Clayton',
#  'Hornsby',
#  'Blackstone Heights',
#  'Leichhardt',
#  'Sydney',
#  'Béni Mellal',
#  'Casablanca',
#  'Oujda',
#  'Rabat',
#  'Sidi Kacem',
#  'Agadir',
#  'Fes',
#  'Quito',
#  'Guayaquil',
#  'Ambato',
#  'Cuenca',
#  'Romoos',
#  'Zürich',
#  'Bern',
#  'Blonay',
#  'Baar',
#  'Basel',
#  "Collina d'Oro",
#  'Antwerpen',
#  'Bruxelles',
#  'Leuven',
#  'Liège',
#  'Aarschot',
#  'Brugge',
#  'Gent',
#  'Stockholm',
#  'Sundbyberg',
#  'Örebro',
#  'Lund',
#  'Solna',
#  'Umeå',
#  'Bangkok',
#  'Chiang Mai',
#  'Muang Pattaya',
#  'Songkhla',
#  'Tambon Bang Prok',
#  'Tambon Takuk Nuea',
#  'Tambon Wichit',
#  'Budapest',
#  'Szeged',
#  'Göd',
#  'Nyíregyháza',
#  'Solymár',
#  'Szombathely',
#  'Veszprém',
#  'Prague',
#  'Brno',
#  'Blansko',
#  'Olomouc',
#  'Pilsen',
#  'Třinec',
#  'Ústí nad Labem',
#  'Pretoria',
#  'Durban',
#  'Bloemfontein',
#  'Cape Town',
#  'Centurion',
#  'George',
#  'Johannesburg',
#  'Ljubljana',
#  'Gabrovka',
#  'Murska Sobota',
#  'Nova Gorica',
#  'Ptuj',
#  'Škofja Loka',
#  'Donji Čehi',
#  'Zagreb',
#  'Gornje Primišlje',
#  'Adžamovci',
#  'Jesenice',
#  'Kamen',
#  'Wien',
#  'Edelsbach bei Graz',
#  'Baden',
#  'Innsbruck',
#  'Salzburg',
#  'Beijing',
#  'Shanghai',
#  'Dingxi Shi',
#  'Guangzhou Shi',
#  'Nanjing Shi',
#  'Wuhan Shi',
#  'Hangzhou Shi',
#  'Gugal Pimpari',
#  'New Delhi',
#  'Chennai',
#  'Hyderabad',
#  'Bengaluru',
#  'Gurgaon',
#  'Mumbai',
#  'Los Angeles',
#  'Chicago',
#  'Wilmington',
#  'San Jose',
#  'Potwin',
#  'Fremont',
#  'Buffalo',
#  'São Paulo',
#  'Rio de Janeiro',
#  'Porto Alegre',
#  'Brasília',
#  'Curitiba',
#  'Campinas',
#  'Belo Horizonte',
#  'Tehran',
#  'Tiran',
#  'Isfahan',
#  'Tabriz',
#  'Yazd',
#  'Hamedan',
#  'Sanandaj',
#  'Moskva',
#  'Sankt-Peterburg',
#  'Kazan',
#  'Perm',
#  'Nizhnij Novgorod',
#  "Yaroslavl'",
#  'Voronez',
#  'Paris',
#  'Montpellier',
#  'Strasbourg',
#  'Villeurbanne',
#  'Nice',
#  'Toulouse',
#  'Marseille',
#  'Ejido del Centro',
#  'Ciudad de México',
#  'Guadalajara',
#  'Ciudad Cuauhtémoc',
#  'Veracruz',
#  'Monterrey',
#  'Ciudad Juárez',
#  'London',
#  'Gosport',
#  'Newcastle upon Tyne',
#  'Boars Hill',
#  'Plymouth',
#  'Leeds',
#  'Belfast',
#  'Haina (Kloster)',
#  'Berlin',
#  'München',
#  'Frankfurt am Main',
#  'Essen',
#  'Stuttgart',
#  'Münster',
#  'Seoul',
#  'Suncheon',
#  'Suwon',
#  'Busan',
#  'Daejeon',
#  'Incheon',
#  'Yongin-si',
#  'Madrid',
#  'Barcelona',
#  'València',
#  'Sevilla',
#  'Las Palmas de Gran Canaria',
#  'Bilbo',
#  'Valladolid',
#  'Roma',
#  'Milano',
#  'Napoli',
#  'Padova',
#  'Udine',
#  'Genova',
#  'Baselga del Bondone',
#  'Kuala Lumpur',
#  'Balingian',
#  'Puchong',
#  'Johor Bahru',
#  'Shah Alam',
#  'Jitra',
#  'Petaling Jaya',
#  'Toronto',
#  'Montreal',
#  'Montréal',
#  'Waterloo',
#  'Burnaby',
#  'Edmonton',
#  'Ottawa',
#  'Amsterdam',
#  'Alblasserdam',
#  'Utrecht',
#  'Groningen',
#  'Tilburg',
#  'Zwijndrecht',
#  'Arnhem',
#  'Bogotá',
#  'Medellín',
#  'Cali',
#  'Bucaramanga',
#  'Pereira',
#  'Manizales',
#  'Neiva',
#  'Lahore',
#  'Karachi',
#  'Faisalabad',
#  'Islamabad',
#  'Rawalpindi',
#  'Peshawar',
#  'Wān',
#  'Lisboa',
#  'Porto',
#  'Braga',
#  'Parede',
#  'Aveiro',
#  'Caparica',
#  'Lagos',
#  'Algiers',
#  'Oran',
#  'Chlef',
#  'Annaba',
#  'Batna',
#  'Béchar',
#  'Constantine',
#  'Santiago',
#  'Concepción',
#  'Viña del Mar',
#  'Temuco',
#  'Antofagasta',
#  'Chiguayante',
#  'La Serena',
#  'Singapore',
#  'Buenos Aires',
#  'Córdoba',
#  'Alta Gracia',
#  'Campana',
#  'Claypole',
#  'Federal',
#  'Ituzaingó',
#  'Shinjuku-ku',
#  'Chiyoda-ku',
#  'Ōsaka-shi',
#  'Ōta-ku',
#  'Yokohama-shi',
#  'Utsunomiya-shi',
#  'Sagamihara-shi',
#  'Craiova',
#  'Târgu Gânguleşti',
#  'București',
#  'Cluj-Napoca',
#  'Timișoara',
#  'Aroneanu',
#  'Chitid',
#  'Athina',
#  'Thessaloniki',
#  'Patra',
#  'Iraklio',
#  'Ioannina',
#  'Chania',
#  'Larisa',
#  'Warszawa',
#  'Wrocław',
#  'Warząchewka Polska',
#  'Poznań',
#  'Gdańsk',
#  'Zielona Góra',
#  'Kraków',
#  'Tunis',
#  'Manouba',
#  'Gafsa',
#  'Sfax',
#  'Manila',
#  'Quezon City',
#  'Makati',
#  'Pasig',
#  'Marikina',
#  'Mandaluyong',
#  'Antipolo',
#  'Distrito de Lima',
#  'Rímac',
#  'Lima',
#  'Callao',
#  'Cercado de Lima',
#  'Distrito de Víctor Larco Herrera',
#  'Kyiv',
#  'Kharkiv',
#  "L'viv",
#  "Alchevs'k",
#  'Chernihiv',
#  'Odesa',
#  'Sumy',
#  'Hanoi',
#  'Ho Chi Minh City',
#  'Da Nang',
#  'Melbourne',
#  'Alexandria',
#  'Clayton',
#  'Hornsby',
#  'Blackstone Heights',
#  'Leichhardt',
#  'Sydney',
#  'Béni Mellal',
#  'Casablanca',
#  'Oujda',
#  'Rabat',
#  'Sidi Kacem',
#  'Agadir',
#  'Fes',
#  'Quito',
#  'Guayaquil',
#  'Ambato',
#  'Cuenca',
#  'Romoos',
#  'Zürich',
#  'Bern',
#  'Blonay',
#  'Baar',
#  'Basel',
#  "Collina d'Oro",
#  'Antwerpen',
#  'Bruxelles',
#  'Leuven',
#  'Liège',
#  'Aarschot',
#  'Brugge',
#  'Gent',
#  'Stockholm',
#  'Sundbyberg',
#  'Örebro',
#  'Lund',
#  'Solna',
#  'Umeå',
#  'Bangkok',
#  'Chiang Mai',
#  'Muang Pattaya',
#  'Songkhla',
#  'Tambon Bang Prok',
#  'Tambon Takuk Nuea',
#  'Tambon Wichit',
#  'Budapest',
#  'Szeged',
#  'Göd',
#  'Nyíregyháza',
#  'Solymár',
#  'Szombathely',
#  'Veszprém',
#  'Prague',
#  'Brno',
#  'Blansko',
#  'Olomouc',
#  'Pilsen',
#  'Třinec',
#  'Ústí nad Labem',
#  'Pretoria',
#  'Durban',
#  'Bloemfontein',
#  'Cape Town',
#  'Centurion',
#  'George',
#  'Johannesburg',
#  'Ljubljana',
#  'Gabrovka',
#  'Murska Sobota',
#  'Nova Gorica',
#  'Ptuj',
#  'Škofja Loka',
#  'Donji Čehi',
#  'Zagreb',
#  'Gornje Primišlje',
#  'Adžamovci',
#  'Jesenice',
#  'Kamen',
#  'Wien',
#  'Edelsbach bei Graz',
#  'Baden',
#  'Innsbruck',
#  'Salzburg',
#  'Beijing',
#  'Shanghai',
#  'Dingxi Shi',
#  'Guangzhou Shi',
#  'Nanjing Shi',
#  'Wuhan Shi',
#  'Hangzhou Shi',
#  'Gugal Pimpari',
#  'New Delhi',
#  'Chennai',
#  'Hyderabad',
#  'Bengaluru',
#  'Gurgaon',
#  'Mumbai',
#  'Los Angeles',
#  'Chicago',
#  'Wilmington',
#  'San Jose',
#  'Potwin',
#  'Fremont',
#  'Buffalo',
#  'São Paulo',
#  'Rio de Janeiro',
#  'Porto Alegre',
#  'Brasília',
#  'Curitiba',
#  'Campinas',
#  'Belo Horizonte',
#  'Tehran',
#  'Tiran',
#  'Isfahan',
#  'Tabriz',
#  'Yazd',
#  'Hamedan',
#  'Sanandaj',
#  'Moskva',
#  'Sankt-Peterburg',
#  'Kazan',
#  'Perm',
#  'Nizhnij Novgorod',
#  "Yaroslavl'",
#  'Voronez',
#  'Paris',
#  'Montpellier',
#  'Strasbourg',
#  'Villeurbanne',
#  'Nice',
#  'Toulouse',
#  'Marseille',
#  'Ejido del Centro',
#  'Ciudad de México',
#  'Guadalajara',
#  'Ciudad Cuauhtémoc',
#  'Veracruz',
#  'Monterrey',
#  'Ciudad Juárez',
#  'London',
#  'Gosport',
#  'Newcastle upon Tyne',
#  'Boars Hill',
#  'Plymouth',
#  'Leeds',
#  'Belfast',
#  'Haina (Kloster)',
#  'Berlin',
#  'München',
#  'Frankfurt am Main',
#  'Essen',
#  'Stuttgart',
#  'Münster',
#  'Seoul',
#  'Suncheon',
#  'Suwon',
#  'Busan',
#  'Daejeon',
#  'Incheon',
#  'Yongin-si',
#  'Madrid',
#  'Barcelona',
#  'València',
#  'Sevilla',
#  'Las Palmas de Gran Canaria',
#  'Bilbo',
#  'Valladolid',
#  'Roma',
#  'Milano',
#  'Napoli',
#  'Padova',
#  'Udine',
#  'Genova',
#  'Baselga del Bondone',
#  'Kuala Lumpur',
#  'Balingian',
#  'Puchong',
#  'Johor Bahru',
#  'Shah Alam',
#  'Jitra',
#  'Petaling Jaya',
#  'Toronto',
#  'Montreal',
#  'Montréal',
#  'Waterloo',
#  'Burnaby',
#  'Edmonton',
#  'Ottawa',
#  'Amsterdam',
#  'Alblasserdam',
#  'Utrecht',
#  'Groningen',
#  'Tilburg',
#  'Zwijndrecht',
#  'Arnhem',
#  'Bogotá',
#  'Medellín',
#  'Cali',
#  'Bucaramanga',
#  'Pereira',
#  'Manizales',
#  'Neiva',
#  'Lahore',
#  'Karachi',
#  'Faisalabad',
#  'Islamabad',
#  'Rawalpindi',
#  'Peshawar',
#  'Wān',
#  'Lisboa',
#  'Porto',
#  'Braga',
#  'Parede',
#  'Aveiro',
#  'Caparica',
#  'Lagos',
#  'Algiers',
#  'Oran',
#  'Chlef',
#  'Annaba',
#  'Batna',
#  'Béchar',
#  'Constantine',
#  'Santiago',
#  'Concepción',
#  'Viña del Mar',
#  'Temuco',
#  'Antofagasta',
#  'Chiguayante',
#  'La Serena',
#  'Singapore',
#  'Buenos Aires',
#  'Córdoba',
#  'Alta Gracia',
#  'Campana',
#  'Claypole',
#  'Federal',
#  'Ituzaingó',
#  'Shinjuku-ku',
#  'Chiyoda-ku',
#  'Ōsaka-shi',
#  'Ōta-ku',
#  'Yokohama-shi',
#  'Utsunomiya-shi',
#  'Sagamihara-shi',
#  'Craiova',
#  'Târgu Gânguleşti',
#  'București',
#  'Cluj-Napoca',
#  'Timișoara',
#  'Aroneanu',
#  'Chitid',
#  'Athina',
#  'Thessaloniki',
#  'Patra',
#  'Iraklio',
#  'Ioannina',
#  'Chania',
#  'Larisa',
#  'Warszawa',
#  'Wrocław',
#  'Warząchewka Polska',
#  'Poznań',
#  'Gdańsk',
#  'Zielona Góra',
#  'Kraków',
#  'Tunis',
#  'Manouba',
#  'Gafsa',
#  'Sfax',
#  'Manila',
#  'Quezon City',
#  'Makati',
#  'Pasig',
#  'Marikina',
#  'Mandaluyong',
#  'Antipolo',
#  'Distrito de Lima',
#  'Rímac',
#  'Lima',
#  'Callao',
#  'Cercado de Lima',
#  'Distrito de Víctor Larco Herrera',
#  'Kyiv',
#  'Kharkiv',
#  "L'viv",
#  "Alchevs'k",
#  'Chernihiv',
#  'Odesa',
#  'Sumy',
#  'Hanoi',
#  'Ho Chi Minh City',
#  'Da Nang',
#  'Melbourne',
#  'Alexandria',
#  'Clayton',
#  'Hornsby',
#  'Blackstone Heights',
#  'Leichhardt',
#  'Sydney',
#  'Béni Mellal',
#  'Casablanca',
#  'Oujda',
#  'Rabat',
#  'Sidi Kacem',
#  'Agadir',
#  'Fes',
#  'Quito',
#  'Guayaquil',
#  'Ambato',
#  'Cuenca',
#  'Romoos',
#  'Zürich',
#  'Bern',
#  'Blonay',
#  'Baar',
#  'Basel',
#  "Collina d'Oro",
#  'Antwerpen',
#  'Bruxelles',
#  'Leuven',
#  'Liège',
#  'Aarschot',
#  'Brugge',
#  'Gent',
#  'Stockholm',
#  'Sundbyberg',
#  'Örebro',
#  'Lund',
#  'Solna',
#  'Umeå',
#  'Bangkok',
#  'Chiang Mai',
#  'Muang Pattaya',
#  'Songkhla',
#  'Tambon Bang Prok',
#  'Tambon Takuk Nuea',
#  'Tambon Wichit',
#  'Budapest',
#  'Szeged',
#  'Göd',
#  'Nyíregyháza',
#  'Solymár',
#  'Szombathely',
#  'Veszprém',
#  'Prague',
#  'Brno',
#  'Blansko',
#  'Olomouc',
#  'Pilsen',
#  'Třinec',
#  'Ústí nad Labem',
#  'Pretoria',
#  'Durban',
#  'Bloemfontein',
#  'Cape Town',
#  'Centurion',
#  'George',
#  'Johannesburg',
#  'Ljubljana',
#  'Gabrovka',
#  'Murska Sobota',
#  'Nova Gorica',
#  'Ptuj',
#  'Škofja Loka',
#  'Donji Čehi',
#  'Zagreb',
#  'Gornje Primišlje',
#  'Adžamovci',
#  'Jesenice',
#  'Kamen',
#  'Wien',
#  'Edelsbach bei Graz',
#  'Baden',
#  'Innsbruck',
#  'Salzburg',
#  'Beijing',
#  'Shanghai',
#  'Dingxi Shi',
#  'Guangzhou Shi',
#  'Nanjing Shi',
#  'Wuhan Shi',
#  'Hangzhou Shi',
#  'Gugal Pimpari',
#  'New Delhi',
#  'Chennai',
#  'Hyderabad',
#  'Bengaluru',
#  'Gurgaon',
#  'Mumbai',
#  'Los Angeles',
#  'Chicago',
#  'Wilmington',
#  'San Jose',
#  'Potwin',
#  'Fremont',
#  'Buffalo',
#  'São Paulo',
#  'Rio de Janeiro',
#  'Porto Alegre',
#  'Brasília',
#  'Curitiba',
#  'Campinas',
#  'Belo Horizonte',
#  'Tehran',
#  'Tiran',
#  'Isfahan',
#  'Tabriz',
#  'Yazd',
#  'Hamedan',
#  'Sanandaj',
#  'Moskva',
#  'Sankt-Peterburg',
#  'Kazan',
#  'Perm',
#  'Nizhnij Novgorod',
#  "Yaroslavl'",
#  'Voronez',
#  'Paris',
#  'Montpellier',
#  'Strasbourg',
#  'Villeurbanne',
#  'Nice',
#  'Toulouse',
#  'Marseille',
#  'Ejido del Centro',
#  'Ciudad de México',
#  'Guadalajara',
#  'Ciudad Cuauhtémoc',
#  'Veracruz',
#  'Monterrey',
#  'Ciudad Juárez',
#  'London',
#  'Gosport',
#  'Newcastle upon Tyne',
#  'Boars Hill',
#  'Plymouth',
#  'Leeds',
#  'Belfast',
#  'Haina (Kloster)',
#  'Berlin',
#  'München',
#  'Frankfurt am Main',
#  'Essen',
#  'Stuttgart',
#  'Münster',
#  'Seoul',
#  'Suncheon',
#  'Suwon',
#  'Busan',
#  'Daejeon',
#  'Incheon',
#  'Yongin-si',
#  'Madrid',
#  'Barcelona',
#  'València',
#  'Sevilla',
#  'Las Palmas de Gran Canaria',
#  'Bilbo',
#  'Valladolid',
#  'Roma',
#  'Milano',
#  'Napoli',
#  'Padova',
#  'Udine',
#  'Genova',
#  'Baselga del Bondone',
#  'Kuala Lumpur',
#  'Balingian',
#  'Puchong',
#  'Johor Bahru',
#  'Shah Alam',
#  'Jitra',
#  'Petaling Jaya',
#  'Toronto',
#  'Montreal',
#  'Montréal',
#  'Waterloo',
#  'Burnaby',
#  'Edmonton',
#  'Ottawa',
#  'Amsterdam',
#  'Alblasserdam',
#  'Utrecht',
#  'Groningen',
#  'Tilburg',
#  'Zwijndrecht',
#  'Arnhem',
#  'Bogotá',
#  'Medellín',
#  'Cali',
#  'Bucaramanga',
#  'Pereira',
#  'Manizales',
#  'Neiva',
#  'Lahore',
#  'Karachi',
#  ...]

# %% [markdown]
# As seen above - Indonesia, Hong Kong, Taiwan, Turkey, Egypt - are missing values for 'city':

# %% [markdown]
# # Filling cities

# %%
indonesia = statistics2017.loc[statistics2017.country == "Indonesia",("lat","lon")].sort_values(by=('lat'))

# %%
indonesia.drop_duplicates().head()
# Out:
#            lat         lon
# 4995 -8.584606  116.116740
# 418  -8.134133  112.599007
# 5253 -7.978261  112.627314
# 5142 -7.803725  110.369443
# 5514 -7.784806  110.359181

# %%
for i in statistics2017.drop_duplicates():
    lat=statistics2017.lat
    lon=statistics2017.lon

# %% [markdown]
# ### Geographic visualization of downloads in top cities of top countries

# %%
from collections import Counter

fig = plt.figure(figsize=(8, 12))

ax = plt.axes(projection=ccrs.Miller())
ax.stock_img()
ax.coastlines( color='black', linewidth=0.1)
ax.add_feature(cfeature.BORDERS, linestyle=':', linewidth=0.1 )

c = Counter(zip(lon,lat))
area = [0.01 * c[(lonlon,latlat)]**2 for lonlon,latlat in zip(lon,lat)]


for i in statistics2017.drop_duplicates():
    lat=statistics2017.lat
    lon=statistics2017.lon
    plt.scatter(lon, lat, color="darkred" ,marker='.', s=area)
plt.title("World Article Consumption Estimate")
         
plt.savefig('./../../../../Dropbox/Print/scihub_downloadmap.pdf')


plt.show()
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-459-6d543a6c8045> in <module>()
#      18 plt.title("World Article Consumption Estimate")
#      19
# ---> 20 plt.savefig('./../../../../Dropbox/Print/scihub_downloadmap.pdf')
#      21
#      22
#
# C:\anaconda\lib\site-packages\matplotlib\pyplot.py in savefig(*args, **kwargs)
#     699 def savefig(*args, **kwargs):
#     700     fig = gcf()
# --> 701     res = fig.savefig(*args, **kwargs)
#     702     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     703     return res
#
# C:\anaconda\lib\site-packages\matplotlib\figure.py in savefig(self, fname, **kwargs)
#    1832             self.set_frameon(frameon)
#    1833
# -> 1834         self.canvas.print_figure(fname, **kwargs)
#    1835
#    1836         if frameon:
#
# C:\anaconda\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2265                 orientation=orientation,
#    2266                 bbox_inches_restore=_bbox_inches_restore,
# -> 2267                 **kwargs)
#    2268         finally:
#    2269             if bbox_inches and restore_bbox:
#
# C:\anaconda\lib\site-packages\matplotlib\backends\backend_pdf.py in print_pdf(self, filename, **kwargs)
#    2582             file = filename._file
#    2583         else:
# -> 2584             file = PdfFile(filename, metadata=kwargs.pop("metadata", None))
#    2585         try:
#    2586             file.newPage(width, height)
#
# C:\anaconda\lib\site-packages\matplotlib\backends\backend_pdf.py in __init__(self, filename, metadata)
#     437         self.tell_base = 0
#     438         if isinstance(filename, six.string_types):
# --> 439             fh = open(filename, 'wb')
#     440         elif is_writable_file_like(filename):
#     441             try:
#
# PermissionError: [Errno 13] Permission denied: './../../../../Dropbox/Print/scihub_downloadmap.pdf'

# %%
import googlemaps
from datetime import datetime
gmaps = googlemaps.Client(key='AIzaSyBwIIrmgKGgeA3YBiVbb_Zp1noehsDgzyk')

# %%
def reverse_geocoide(lon, lat):
    reverse_geocode_result = gmaps.reverse_geocode((lat, lon))
    reverse_geocode_result

# %%
statistics2017["city"]["c"] = city_entry

# %%
res = gmaps.reverse_geocode((-8.134133,112.599007))

# %%
for i in res:
    print(i)
# Out:
# {'address_components': [{'long_name': 'Jalan Sunan Kalijaga', 'short_name': 'Jl. Sunan Kalijaga', 'types': ['route']}, {'long_name': 'Bulupitu', 'short_name': 'Bulupitu', 'types': ['administrative_area_level_4', 'political']}, {'long_name': 'Gondanglegi', 'short_name': 'Gondanglegi', 'types': ['administrative_area_level_3', 'political']}, {'long_name': 'Malang', 'short_name': 'Malang', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'Jawa Timur', 'short_name': 'Jawa Timur', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'Indonesia', 'short_name': 'ID', 'types': ['country', 'political']}, {'long_name': '65174', 'short_name': '65174', 'types': ['postal_code']}], 'formatted_address': 'Jl. Sunan Kalijaga, Bulupitu, Gondanglegi, Malang, Jawa Timur 65174, Indonesia', 'geometry': {'bounds': {'northeast': {'lat': -8.133844800000002, 'lng': 112.5991094}, 'southwest': {'lat': -8.1341992, 'lng': 112.5987069}}, 'location': {'lat': -8.134022, 'lng': 112.5989081}, 'location_type': 'GEOMETRIC_CENTER', 'viewport': {'northeast': {'lat': -8.132673019708498, 'lng': 112.6002571302915}, 'southwest': {'lat': -8.135370980291503, 'lng': 112.5975591697085}}}, 'place_id': 'ChIJxULtqsmfeC4RGGFS9clIrCM', 'types': ['route']}
# {'address_components': [{'long_name': 'Bulupitu', 'short_name': 'Bulupitu', 'types': ['administrative_area_level_4', 'political']}, {'long_name': 'Gondanglegi', 'short_name': 'Gondanglegi', 'types': ['administrative_area_level_3', 'political']}, {'long_name': 'Malang', 'short_name': 'Malang', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'East Java', 'short_name': 'East Java', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'Indonesia', 'short_name': 'ID', 'types': ['country', 'political']}], 'formatted_address': 'Bulupitu, Gondanglegi, Malang, East Java, Indonesia', 'geometry': {'bounds': {'northeast': {'lat': -8.1238171, 'lng': 112.615179}, 'southwest': {'lat': -8.157384, 'lng': 112.589422}}, 'location': {'lat': -8.134133199999999, 'lng': 112.5990066}, 'location_type': 'APPROXIMATE', 'viewport': {'northeast': {'lat': -8.1238171, 'lng': 112.615179}, 'southwest': {'lat': -8.157384, 'lng': 112.589422}}}, 'place_id': 'ChIJ-Sm7HsSfeC4RFuvzN_1S1pc', 'types': ['administrative_area_level_4', 'political']}
# {'address_components': [{'long_name': 'Gondanglegi', 'short_name': 'Gondanglegi', 'types': ['administrative_area_level_3', 'political']}, {'long_name': 'Malang', 'short_name': 'Malang', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'East Java', 'short_name': 'East Java', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'Indonesia', 'short_name': 'ID', 'types': ['country', 'political']}], 'formatted_address': 'Gondanglegi, Malang, East Java, Indonesia', 'geometry': {'bounds': {'northeast': {'lat': -8.109784, 'lng': 112.675296}, 'southwest': {'lat': -8.206252, 'lng': 112.5707539}}, 'location': {'lat': -8.1551922, 'lng': 112.6317838}, 'location_type': 'APPROXIMATE', 'viewport': {'northeast': {'lat': -8.109784, 'lng': 112.675296}, 'southwest': {'lat': -8.206252, 'lng': 112.5707539}}}, 'place_id': 'ChIJh8qKVAYg1i0RGIj97HJEVCw', 'types': ['administrative_area_level_3', 'political']}
# {'address_components': [{'long_name': '65174', 'short_name': '65174', 'types': ['postal_code']}, {'long_name': 'Malang', 'short_name': 'Malang', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'East Java', 'short_name': 'East Java', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'Indonesia', 'short_name': 'ID', 'types': ['country', 'political']}], 'formatted_address': 'Malang, East Java 65174, Indonesia', 'geometry': {'bounds': {'northeast': {'lat': -8.111165999999999, 'lng': 112.6768798}, 'southwest': {'lat': -8.2406157, 'lng': 112.5526732}}, 'location': {'lat': -8.1756177, 'lng': 112.6317838}, 'location_type': 'APPROXIMATE', 'viewport': {'northeast': {'lat': -8.111165999999999, 'lng': 112.6768798}, 'southwest': {'lat': -8.2406157, 'lng': 112.5526732}}}, 'place_id': 'ChIJMXNJHAGgeC4R4BNUW-vFABw', 'types': ['postal_code']}
# {'address_components': [{'long_name': 'Malang', 'short_name': 'Malang', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'East Java', 'short_name': 'East Java', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'Indonesia', 'short_name': 'ID', 'types': ['country', 'political']}], 'formatted_address': 'Malang, East Java, Indonesia', 'geometry': {'bounds': {'northeast': {'lat': -7.761077999999999, 'lng': 112.958174}, 'southwest': {'lat': -8.46401, 'lng': 112.287407}}, 'location': {'lat': -8.242208999999999, 'lng': 112.7152125}, 'location_type': 'APPROXIMATE', 'viewport': {'northeast': {'lat': -7.761077999999999, 'lng': 112.958174}, 'southwest': {'lat': -8.46401, 'lng': 112.287407}}}, 'place_id': 'ChIJ2XD8XZsg1i0RsL1S43Z6AgM', 'types': ['administrative_area_level_2', 'political']}
# {'address_components': [{'long_name': 'East Java', 'short_name': 'East Java', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'Indonesia', 'short_name': 'ID', 'types': ['country', 'political']}], 'formatted_address': 'East Java, Indonesia', 'geometry': {'bounds': {'northeast': {'lat': -5.048857, 'lng': 116.267761}, 'southwest': {'lat': -8.780560999999999, 'lng': 110.8987199}}, 'location': {'lat': -7.5360639, 'lng': 112.2384017}, 'location_type': 'APPROXIMATE', 'viewport': {'northeast': {'lat': -5.048857, 'lng': 116.267761}, 'southwest': {'lat': -8.780560999999999, 'lng': 110.8987199}}}, 'place_id': 'ChIJxbXun_eToy0RULh8yvsLAwE', 'types': ['administrative_area_level_1', 'political']}
# {'address_components': [{'long_name': 'Indonesia', 'short_name': 'ID', 'types': ['country', 'political']}], 'formatted_address': 'Indonesia', 'geometry': {'bounds': {'northeast': {'lat': 6.216999899999999, 'lng': 141.0425}, 'southwest': {'lat': -11.1082999, 'lng': 94.7351}}, 'location': {'lat': -0.789275, 'lng': 113.921327}, 'location_type': 'APPROXIMATE', 'viewport': {'northeast': {'lat': 6.216999899999999, 'lng': 141.0425}, 'southwest': {'lat': -11.1082999, 'lng': 94.7351}}}, 'place_id': 'ChIJtwRkSdcHTCwRhfStG-dNe-M', 'types': ['country', 'political']}

# %%
ax = plt.axes(projection=ccrs.PlateCarree())
ax.coastlines()

# %%
import cartopy.feature as cfeature

ax = plt.axes(projection=ccrs.PlateCarree())
ax.coastlines()
ax.add_feature(cfeature.BORDERS, linestyle=':' )
ax.add_feature(cfeature.RIVERS)
for i in indonesia.drop_duplicates():
    lat=indonesia.lat
    lon=indonesia.lon
    plt.scatter(lon, lat)
# Out:
# C:\anaconda\lib\site-packages\cartopy\io\__init__.py:260: DownloadWarning: Downloading: http://naciscdn.org/naturalearth/110m/physical/ne_110m_rivers_lake_centerlines.zip
#   warnings.warn('Downloading: {}'.format(url), DownloadWarning)
