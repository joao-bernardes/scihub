# %% [markdown]
# ## Loading the DataFrame (Sci-hub)

# %%
from IPython.display import display

import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

# %%
articles = pd.read_table("../data/full/scihub_all.tab", usecols=[2,1], header=None)

# %%
#give columns names
articles.columns = ["DOI", "userID"]

# %% [markdown]
# ## Fixing Columns (["DOI_prefix"])

# %%
#isolate the prefix of the DOI 
articles["DOI_prefix"] = articles["DOI"].map(lambda x: str(x).split("/")[0])

# %%
articles.head()
# Out:
#                              DOI         userID DOI_prefix
# 0      10.1007/s10439-013-0829-z  56ed2b74a66a1    10.1007
# 1  10.1016/s0894-7317(12)00840-1  56ed2b712d760    10.1016
# 2      10.1016/j.jmv.2014.04.008  56ed2b6e2d9ab    10.1016
# 3      10.1016/j.gie.2011.12.024  56ed2b6f4d2c4    10.1016
# 4      10.1016/j.vph.2013.01.001  56ed2b02bb5ad    10.1016

# %% [markdown]
# ### pd.merge (DOI_prefix + Prefix)=publisher

# %%
#publisher_prefix = pd.read_csv("doi-prefix-publishers.csv", index_col = 0)                       
#publisher_prefix.tail()

# %%
journal_DOIs = pd.read_csv("../data/publisher_DOI_prefixes.csv", index_col = 0)
#journal_DOIs[journal_DOIs["Name"]== "Elsevier"]
journal_DOIs.head()
# Out:
#                                                 Name    Prefix   Date Joined  \
# 0  Povolzhskiy State University of Telecommunicat...  10.18469           NaN
# 1                   "Henri Coanda" Air Force Academy  10.19062           NaN
# 2                                   123Doc Education   10.7579  May 16, 2012
# 3  21st Century COE Program (Toplogical Science a...   10.3731  Nov 20, 2007
# 4         21st Century Political Science Association  10.17937           NaN
#
#   Date of \nLast Deposit Date of \nLast Query
# 0           Dec 16, 2015              unknown
# 1           Jan 05, 2016              unknown
# 2                unknown              unknown
# 3                unknown              unknown
# 4           Sep 14, 2015              unknown

# %%
articles = pd.merge(articles, journal_DOIs[["Prefix","Name"]],
                               left_on = "DOI_prefix", right_on = "Prefix", how = "left")
articles = articles.drop(columns=["Prefix"])
articles = articles.drop(columns=["DOI_prefix"])
articles = articles.rename({"Name": "publisher"}, axis = "columns")
articles
#data_publishers[["prefix","downloads","Name"]].to_csv("scihub_data_temp/%s_publishers.csv" %(month))
# Out:
#                                          DOI         userID  \
# 0                  10.1007/s10439-013-0829-z  56ed2b74a66a1
# 1                  10.1007/s10439-013-0829-z  56ed2b74a66a1
# 2              10.1016/s0894-7317(12)00840-1  56ed2b712d760
# 3                  10.1016/j.jmv.2014.04.008  56ed2b6e2d9ab
# 4                  10.1016/j.gie.2011.12.024  56ed2b6f4d2c4
# 5                  10.1016/j.vph.2013.01.001  56ed2b02bb5ad
# 6                 10.1016/j.jada.2004.05.056  56ed2b74a4d40
# 7                 10.1016/j.jflm.2011.12.018  56ed2b64dc78f
# 8            10.1016/j.euroneuro.2014.05.008  56ed2b6e9207e
# 9               10.1016/j.emcrad.2005.09.002  56ed2b0d39853
# 10             10.1016/S0266-7681(84)80036-4  56ed2b0ed44f4
# 11                    10.1542/peds.2011-1262  56ed2b74b49f8
# 12           10.1016/j.quascirev.2012.04.006  56ed2b70ba88a
# 13               10.1007/978-1-4615-0215-9_4  56ed2b74b12b5
# 14               10.1007/978-1-4615-0215-9_4  56ed2b74b12b5
# 15              10.1016/j.phytol.2012.04.011  56ed2b70ef136
# 16                         10.1643/OT-14-084  56ed2b5278983
# 17             10.1016/S1574-0676(06)01018-0  56ed2b74b4aa6
# 18               10.1016/j.toxac.2014.07.002  56ed2b6e2d744
# 19            10.1016/j.foodchem.2008.02.053  56ed2b749f89b
# 20                 10.1007/s11065-007-9020-3  56ed2b0e8e170
# 21                 10.1007/s11065-007-9020-3  56ed2b0e8e170
# 22        10.1016/b978-0-12-415916-7.00001-2  56ed2b70bbf23
# 23             10.1016/S0174-3031(82)80133-9  56ed2b6fda9a8
# 24          10.1016/j.drugalcdep.2014.09.015  56ed2b6e2d9ab
# 25             10.1016/j.physbeh.2005.06.018  56ed2b74a4d40
# 26                 10.1080/10643380290813462  56ed2b386a1bd
# 27              10.1016/0020-7683(94)90203-8  56ed2b749ea42
# 28                10.1016/j.ejpb.2008.09.004  56ed2b74761ac
# 29                         10.1021/cm504510f  56ed2b4a3723d
# ...                                      ...            ...
# 32711628                     10.1038/416389a  56ed2d2a40f34
# 32711629                     10.1038/416389a  56ed2d2a40f34
# 32711630        10.1007/978-1-4757-4716-4_14  56ed2cd7b81f4
# 32711631        10.1007/978-1-4757-4716-4_14  56ed2cd7b81f4
# 32711632       10.1016/S0399-8320(06)73191-8  56ed2d2a40fee
# 32711633               10.1089/jmf.2011.1717  56ed2d2a00045
# 32711634          10.1016/j.jeca.2015.10.003  56ed2d2a4108e
# 32711635                     10.4171/GGD/136  56ed2b4c7b54c
# 32711636           10.1017/S0020818300033324  56ed2b53ebbee
# 32711637    10.1016/j.cryogenics.2015.07.003  56ed2d2a2911c
# 32711638        10.1016/0020-7403(90)90148-C  56ed2c7a588b1
# 32711639                    10.1038/nbt.2842  56ed2c73c25df
# 32711640                    10.1038/nbt.2842  56ed2c73c25df
# 32711641          10.1016/j.jtcc.2015.12.003  56eda00b01a32
# 32711642                10.1038/ajg.2010.497  56ed2cfd346a6
# 32711643                10.1038/ajg.2010.497  56ed2cfd346a6
# 32711644                  10.1007/BF00269500  56ed2b8814e57
# 32711645                  10.1007/BF00269500  56ed2b8814e57
# 32711646          10.1177/073401689702200108  56ed2c5e39844
# 32711647                    10.1038/273613a0  56ed2d2a3d37e
# 32711648                    10.1038/273613a0  56ed2d2a3d37e
# 32711649      10.1088/0957-4484/22/27/275718  56ed2d1a2dce8
# 32711650       10.1016/S0141-0296(01)00121-3  56ed2b0320c78
# 32711651           10.1016/j.dld.2013.06.007  56ed2d2a4112c
# 32711652             10.1109/TEC.2005.858072  56ed2c362165b
# 32711653                     10.1139/f75-001  56ed2b41cbe0d
# 32711654       10.1016/S1003-6326(13)62893-9  56ed2d2a047f5
# 32711655         10.1080/0013188032000137256  56ed2b06abda5
# 32711656          10.1016/j.jscs.2012.10.010  56ed2c56744c9
# 32711657                   10.1021/jf0616098  56ed2b37b6da5
#
#                                                   publisher
# 0                                           Springer-Verlag
# 1                                           Springer-Verlag
# 2                                                  Elsevier
# 3                                                  Elsevier
# 4                                                  Elsevier
# 5                                                  Elsevier
# 6                                                  Elsevier
# 7                                                  Elsevier
# 8                                                  Elsevier
# 9                                                  Elsevier
# 10                                                 Elsevier
# 11                           American Academy of Pediatrics
# 12                                                 Elsevier
# 13                                          Springer-Verlag
# 14                                          Springer-Verlag
# 15                                                 Elsevier
# 16        BioOne (American Society of Icthyologists and ...
# 17                                                 Elsevier
# 18                                                 Elsevier
# 19                                                 Elsevier
# 20                                          Springer-Verlag
# 21                                          Springer-Verlag
# 22                                                 Elsevier
# 23                                                 Elsevier
# 24                                                 Elsevier
# 25                                                 Elsevier
# 26                            Informa UK (Taylor & Francis)
# 27                                                 Elsevier
# 28                                                 Elsevier
# 29                                American Chemical Society
# ...                                                     ...
# 32711628                            Nature Publishing Group
# 32711629                            Nature Publishing Group
# 32711630                                    Springer-Verlag
# 32711631                                    Springer-Verlag
# 32711632                                           Elsevier
# 32711633                                   Mary Ann Liebert
# 32711634                                           Elsevier
# 32711635     European Mathematical Society Publishing House
# 32711636                         Cambridge University Press
# 32711637                                           Elsevier
# 32711638                                           Elsevier
# 32711639                            Nature Publishing Group
# 32711640                            Nature Publishing Group
# 32711641                                           Elsevier
# 32711642                            Nature Publishing Group
# 32711643                            Nature Publishing Group
# 32711644                                    Springer-Verlag
# 32711645                                    Springer-Verlag
# 32711646                                  SAGE Publications
# 32711647                            Nature Publishing Group
# 32711648                            Nature Publishing Group
# 32711649                                     IOP Publishing
# 32711650                                           Elsevier
# 32711651                                           Elsevier
# 32711652  Institute of Electrical and Electronics Engineers
# 32711653                        Canadian Science Publishing
# 32711654                                           Elsevier
# 32711655                      Informa UK (Taylor & Francis)
# 32711656                                           Elsevier
# 32711657                          American Chemical Society
#
# [32711658 rows x 3 columns]

# %%
#top_publisher = data.groupby("DOI_prefix").count()
top_publisher = articles.groupby(["publisher"]).count().sort_values("userID", ascending=False).userID
top_publisher.head(20).plot("pie", figsize=(30,30), fontsize=(20))
#Se multiplicar-mos por 2600 o número de downloads obtemos um número mais aproximado do alldata.tab
plt.savefig('./../publisher_coverage.pdf')    
    #Como sacar um país da listagem
    #data[data["country"] !="China"].groupby("continent").count()

# %%
top_publisher.to_csv ("../data/downloads_by_publishers.csv", header=["downloads"])

# %% [markdown]
# # By Paper (DOI)

# %%
top25 = articles.groupby("DOI").count().sort_values(by = "userID", ascending = False)[:25].userID.reset_index()
top25.to_csv("./../data/top25")

# %%
top25
# Out:
#                                        DOI  userID
# 0             10.1007/978-1-4419-9716-6_11   15976
# 1                    10.1056/NEJMoa1402121    6117
# 2         10.1111/j.1365-277X.2004.00520.x    4482
# 3                        10.1116/1.4904970    2991
# 4                10.1007/s10832-012-9736-1    2948
# 5               10.1103/PhysRevB.63.224204    2890
# 6                         10.1038/nmat3258    2674
# 7            10.1182/asheducation-2015.1.8    2528
# 8   10.4028/www.scientific.net/AMM.7-8.159    2266
# 9                   10.1002/pmic.200600525    2168
# 10           10.1161/CIRCRESAHA.117.306290    2001
# 11                  10.1002/smll.201002009    1806
# 12            10.1007/978-3-319-28658-7_55    1708
# 13                  10.1002/3527603433.ch3    1705
# 14                        10.1038/nmat1849    1700
# 15                        10.1038/nbt.2842    1648
# 16                       10.1038/nphys3430    1628
# 17                         10.1038/nn.4065    1620
# 18                     10.1038/nature16961    1512
# 19               10.1007/s11948-014-9521-4    1492
# 20               10.1007/s10677-015-9567-7    1464
# 21                  10.1038/nprot.2013.143    1210
# 22           10.1158/1541-7786.MCR-14-0590    1192
# 23                               10.1016/j    1138
# 24             10.1109/ISPASS.2015.7095803    1131

# %% [markdown]
# ## Importing OA Statuses

# %%
#iteration list:
OA_list = ["oa_status01","oa_status02","oa_status03","oa_status04","oa_status05","oa_status06","oa_status07","oa_status08","oa_status09","oa_status10","oa_status11","oa_status12","oa_status13","oa_status14","oa_status15","oa_status16","oa_status17","oa_status18","oa_status19","oa_status20","oa_status21","oa_status22","oa_status23","oa_status24","oa_status25","oa_status26","oa_status27","oa_status28","oa_status29"]

# %%
def oa_status_read(in_path):
    with open(in_path, encoding="Latin-1") as f:
        oa_status = pd.read_csv(f, header=0)
        return oa_status
    
def merge_them(DataFrame, in_path):
    oa_status = oa_status_read(in_path)
    scihub_oa_status = pd.merge(DataFrame, oa_status,left_on = "DOI", right_on = "doi", how = "left")
    scihub_oa_status = scihub_oa_status.drop(columns="doi")
        
    return scihub_oa_status
    
def gerar_file(base_in_path, DataFrame, file_list):
    for file in file_list:
        in_path = base_in_path + file
        
        #scihub_oa_status = oa_status_read(in_path)
        scihub_oa_status = merge_them(DataFrame, in_path)
        return scihub_oa_status
        #print (in_path)

# %%
articles = gerar_file("./../data/full/OA_status/", articles, OA_list)

# %%
articles
# Out:
#                                          DOI         userID  \
# 0                  10.1007/s10439-013-0829-z  56ed2b74a66a1
# 1                  10.1007/s10439-013-0829-z  56ed2b74a66a1
# 2              10.1016/s0894-7317(12)00840-1  56ed2b712d760
# 3                  10.1016/j.jmv.2014.04.008  56ed2b6e2d9ab
# 4                  10.1016/j.gie.2011.12.024  56ed2b6f4d2c4
# 5                  10.1016/j.vph.2013.01.001  56ed2b02bb5ad
# 6                 10.1016/j.jada.2004.05.056  56ed2b74a4d40
# 7                 10.1016/j.jflm.2011.12.018  56ed2b64dc78f
# 8            10.1016/j.euroneuro.2014.05.008  56ed2b6e9207e
# 9               10.1016/j.emcrad.2005.09.002  56ed2b0d39853
# 10             10.1016/S0266-7681(84)80036-4  56ed2b0ed44f4
# 11                    10.1542/peds.2011-1262  56ed2b74b49f8
# 12           10.1016/j.quascirev.2012.04.006  56ed2b70ba88a
# 13               10.1007/978-1-4615-0215-9_4  56ed2b74b12b5
# 14               10.1007/978-1-4615-0215-9_4  56ed2b74b12b5
# 15              10.1016/j.phytol.2012.04.011  56ed2b70ef136
# 16                         10.1643/OT-14-084  56ed2b5278983
# 17             10.1016/S1574-0676(06)01018-0  56ed2b74b4aa6
# 18               10.1016/j.toxac.2014.07.002  56ed2b6e2d744
# 19            10.1016/j.foodchem.2008.02.053  56ed2b749f89b
# 20                 10.1007/s11065-007-9020-3  56ed2b0e8e170
# 21                 10.1007/s11065-007-9020-3  56ed2b0e8e170
# 22        10.1016/b978-0-12-415916-7.00001-2  56ed2b70bbf23
# 23             10.1016/S0174-3031(82)80133-9  56ed2b6fda9a8
# 24          10.1016/j.drugalcdep.2014.09.015  56ed2b6e2d9ab
# 25             10.1016/j.physbeh.2005.06.018  56ed2b74a4d40
# 26                 10.1080/10643380290813462  56ed2b386a1bd
# 27              10.1016/0020-7683(94)90203-8  56ed2b749ea42
# 28                10.1016/j.ejpb.2008.09.004  56ed2b74761ac
# 29                         10.1021/cm504510f  56ed2b4a3723d
# ...                                      ...            ...
# 32711628                     10.1038/416389a  56ed2d2a40f34
# 32711629                     10.1038/416389a  56ed2d2a40f34
# 32711630        10.1007/978-1-4757-4716-4_14  56ed2cd7b81f4
# 32711631        10.1007/978-1-4757-4716-4_14  56ed2cd7b81f4
# 32711632       10.1016/S0399-8320(06)73191-8  56ed2d2a40fee
# 32711633               10.1089/jmf.2011.1717  56ed2d2a00045
# 32711634          10.1016/j.jeca.2015.10.003  56ed2d2a4108e
# 32711635                     10.4171/GGD/136  56ed2b4c7b54c
# 32711636           10.1017/S0020818300033324  56ed2b53ebbee
# 32711637    10.1016/j.cryogenics.2015.07.003  56ed2d2a2911c
# 32711638        10.1016/0020-7403(90)90148-C  56ed2c7a588b1
# 32711639                    10.1038/nbt.2842  56ed2c73c25df
# 32711640                    10.1038/nbt.2842  56ed2c73c25df
# 32711641          10.1016/j.jtcc.2015.12.003  56eda00b01a32
# 32711642                10.1038/ajg.2010.497  56ed2cfd346a6
# 32711643                10.1038/ajg.2010.497  56ed2cfd346a6
# 32711644                  10.1007/BF00269500  56ed2b8814e57
# 32711645                  10.1007/BF00269500  56ed2b8814e57
# 32711646          10.1177/073401689702200108  56ed2c5e39844
# 32711647                    10.1038/273613a0  56ed2d2a3d37e
# 32711648                    10.1038/273613a0  56ed2d2a3d37e
# 32711649      10.1088/0957-4484/22/27/275718  56ed2d1a2dce8
# 32711650       10.1016/S0141-0296(01)00121-3  56ed2b0320c78
# 32711651           10.1016/j.dld.2013.06.007  56ed2d2a4112c
# 32711652             10.1109/TEC.2005.858072  56ed2c362165b
# 32711653                     10.1139/f75-001  56ed2b41cbe0d
# 32711654       10.1016/S1003-6326(13)62893-9  56ed2d2a047f5
# 32711655         10.1080/0013188032000137256  56ed2b06abda5
# 32711656          10.1016/j.jscs.2012.10.010  56ed2c56744c9
# 32711657                   10.1021/jf0616098  56ed2b37b6da5
#
#                                                   publisher  is_oa
# 0                                           Springer-Verlag   True
# 1                                           Springer-Verlag   True
# 2                                                  Elsevier    NaN
# 3                                                  Elsevier    NaN
# 4                                                  Elsevier  False
# 5                                                  Elsevier    NaN
# 6                                                  Elsevier    NaN
# 7                                                  Elsevier    NaN
# 8                                                  Elsevier    NaN
# 9                                                  Elsevier    NaN
# 10                                                 Elsevier    NaN
# 11                           American Academy of Pediatrics   True
# 12                                                 Elsevier    NaN
# 13                                          Springer-Verlag    NaN
# 14                                          Springer-Verlag    NaN
# 15                                                 Elsevier    NaN
# 16        BioOne (American Society of Icthyologists and ...    NaN
# 17                                                 Elsevier    NaN
# 18                                                 Elsevier    NaN
# 19                                                 Elsevier    NaN
# 20                                          Springer-Verlag    NaN
# 21                                          Springer-Verlag    NaN
# 22                                                 Elsevier    NaN
# 23                                                 Elsevier    NaN
# 24                                                 Elsevier    NaN
# 25                                                 Elsevier    NaN
# 26                            Informa UK (Taylor & Francis)    NaN
# 27                                                 Elsevier    NaN
# 28                                                 Elsevier    NaN
# 29                                American Chemical Society    NaN
# ...                                                     ...    ...
# 32711628                            Nature Publishing Group    NaN
# 32711629                            Nature Publishing Group    NaN
# 32711630                                    Springer-Verlag    NaN
# 32711631                                    Springer-Verlag    NaN
# 32711632                                           Elsevier    NaN
# 32711633                                   Mary Ann Liebert    NaN
# 32711634                                           Elsevier    NaN
# 32711635     European Mathematical Society Publishing House    NaN
# 32711636                         Cambridge University Press    NaN
# 32711637                                           Elsevier    NaN
# 32711638                                           Elsevier    NaN
# 32711639                            Nature Publishing Group    NaN
# 32711640                            Nature Publishing Group    NaN
# 32711641                                           Elsevier    NaN
# 32711642                            Nature Publishing Group    NaN
# 32711643                            Nature Publishing Group    NaN
# 32711644                                    Springer-Verlag    NaN
# 32711645                                    Springer-Verlag    NaN
# 32711646                                  SAGE Publications    NaN
# 32711647                            Nature Publishing Group  False
# 32711648                            Nature Publishing Group  False
# 32711649                                     IOP Publishing    NaN
# 32711650                                           Elsevier    NaN
# 32711651                                           Elsevier    NaN
# 32711652  Institute of Electrical and Electronics Engineers    NaN
# 32711653                        Canadian Science Publishing    NaN
# 32711654                                           Elsevier    NaN
# 32711655                      Informa UK (Taylor & Francis)    NaN
# 32711656                                           Elsevier    NaN
# 32711657                          American Chemical Society    NaN
#
# [32711658 rows x 4 columns]

# %%
#data.dropna(axis=0, how='any').head()
oa_plot = articles.groupby(["is_oa"]).count().userID

oa_plot.plot("pie", figsize=(30,30), fontsize=(20))
