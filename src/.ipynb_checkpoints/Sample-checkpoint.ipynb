# %% [markdown]
# ## Loading the DataFrame (Sci-hub)

# %%
from IPython.display import display

import pandas as pd
import matplotlib
#data = pd.read_table("../data/full/scihub_all.tab", header=None)
data = pd.read_table("../data/data_sample/scihub_sample.tab", header=None)

#give columns names
data.columns = ["date", "DOI", "userID", "country", "city", "GPS"]

#remove parenthsis and special characters
data["country"] = data["country"].str.replace(r" *\(.*\)", "")

# %% [markdown]
# ## Fixing Columns (["DOI_prefix", "latitude", "longitude", "GPS"])

# %%
#isolate the prefix of the DOI 
data["DOI_prefix"] = data["DOI"].map(lambda x: str(x).split("/")[0])

# %%
#divides GPS on latitude ang longitude columns
data[["latitude", "longitude"]] = data.GPS.str.split(",", expand = True)
data = data.drop(columns="GPS")

# %%
data.describe()
# Out:
#                        date                           DOI         userID  \
# count                  6000                          6000           6000
# unique                 5997                          5995           5486
# top     2015-09-09 16:33:04  10.1007/978-1-4419-9716-6_11  56ed2c309a910
# freq                      2                             2             22
#
#        country    city DOI_prefix    latitude   longitude
# count     5889    5057       6000        5889        5889
# unique     110    1034        220        1198        1197
# top      China  Tehran    10.1016  35.6891975  51.3889736
# freq      1010     292       2016         292         292

# %% [markdown]
# ### pd.merge (DOI_prefix + Prefix)=publisher

# %%
#publisher_prefix = pd.read_csv("doi-prefix-publishers.csv", index_col = 0)                       
#publisher_prefix.tail()

# %%
journal_DOIs = pd.read_csv("../data/publisher_DOI_prefixes.csv", index_col = 0)
#journal_DOIs[journal_DOIs["Name"]== "Elsevier"]
journal_DOIs.head()
# Out:
#                                                 Name    Prefix   Date Joined  \
# 0  Povolzhskiy State University of Telecommunicat...  10.18469           NaN
# 1                   "Henri Coanda" Air Force Academy  10.19062           NaN
# 2                                   123Doc Education   10.7579  May 16, 2012
# 3  21st Century COE Program (Toplogical Science a...   10.3731  Nov 20, 2007
# 4         21st Century Political Science Association  10.17937           NaN
#
#   Date of \nLast Deposit Date of \nLast Query
# 0           Dec 16, 2015              unknown
# 1           Jan 05, 2016              unknown
# 2                unknown              unknown
# 3                unknown              unknown
# 4           Sep 14, 2015              unknown

# %%
data_publishers = pd.merge(data, journal_DOIs[["Prefix","Name"]],
                               left_on = "DOI_prefix", right_on = "Prefix", how = "left")
data_publishers = data_publishers.drop(columns=["Prefix"])
data_publishers = data_publishers.drop(columns=["DOI_prefix"])
data_publishers = data_publishers.rename({"Name": "publisher"}, axis = "columns")
data_publishers
#data_publishers[["prefix","downloads","Name"]].to_csv("scihub_data_temp/%s_publishers.csv" %(month))
# Out:
#                      date                                                DOI  \
# 0     2015-09-19 17:45:31                               10.1029/2002WR001317
# 1     2015-09-09 11:17:09                      10.1016/j.jclepro.2014.09.075
# 2     2015-09-10 22:19:01                 10.1016/B978-0-08-095975-7.01310-3
# 3     2015-09-27 17:55:19                         10.1103/PhysRevB.63.224204
# 4     2015-09-14 13:28:52                       10.1183/09031936.06.00011806
# 5     2015-09-11 08:50:40                          10.1016/j.bmc.2011.11.016
# 6     2015-09-17 17:20:42                       10.1016/0022-1902(67)80090-3
# 7     2015-09-10 13:12:16                       10.1016/j.optcom.2011.05.073
# 8     2015-09-11 08:41:30                               10.1039/JR9590001035
# 9     2015-09-11 20:56:49                         10.1016/j.rser.2015.04.093
# 10    2015-09-04 12:22:46                               10.1021/jacs.5b00504
# ...

# %%
#top_publisher = data.groupby("DOI_prefix").count()
top_publisher = data_publishers.groupby(["publisher"]).count().sort_values("date", ascending=False).date
top_publisher.head(20).plot("bar", figsize=(30,30), fontsize=(20))
#Se multiplicar-mos por 2600 o número de downloads obtemos um número mais aproximado do alldata.tab
    
    #Como sacar um país da listagem
    #data[data["country"] !="China"].groupby("continent").count()

# %%
top_publisher.to_csv ("../data/downloads_by_publishers.csv", header=["downloads"])

# %% [markdown]
# # By Paper (DOI)

# %%
top25 = data.groupby("DOI").count().sort_values(by = "date", ascending = False)[:25].date.reset_index()
top25
# Out:
#                                                   DOI  date
# 0                          10.1103/PhysRevB.63.224204     2
# 1                                 10.1038/nature16489     2
# 2   10.1002/1521-3757(20020715)114:14<2708::AID-AN...     2
# 3                        10.1007/978-1-4419-9716-6_11     2
# 4                         10.1109/ISPACS.2013.6704525     2
# 5                             10.1080/000713199358707     1
# 6                       10.1080/00038628.2015.1012637     1
# 7                             10.1073/pnas.1509654112     1
# 8                             10.1073/pnas.1506101112     1
# 9                           10.1080/00107510701662538     1
# 10                            10.1073/pnas.1402724111     1
# 11                            10.1073/pnas.1305316110     1
# 12                             10.1073/pnas.111164198     1
# 13                            10.1073/pnas.0806445106     1
# 14                            10.1073/pnas.0605552103     1
# ...

# %% [markdown]
# ## By Continent

# %%
countries_continent = pd.read_csv('../data/Countries-Continents.csv')
#countries_continent[countries_continent["Continent"]=="Europe"].count()

# %%
data = pd.merge(data, countries_continent,
         left_on = "country", right_on = "Country", how = "left")
data = data.drop(columns="Country")
data = data.rename({"Continent": "continent"}, axis = "columns")

data
# Out:
#                      date                                                DOI  \
# 0     2015-09-19 17:45:31                               10.1029/2002WR001317
# 1     2015-09-09 11:17:09                      10.1016/j.jclepro.2014.09.075
# 2     2015-09-10 22:19:01                 10.1016/B978-0-08-095975-7.01310-3
# 3     2015-09-27 17:55:19                         10.1103/PhysRevB.63.224204
# 4     2015-09-14 13:28:52                       10.1183/09031936.06.00011806
# 5     2015-09-11 08:50:40                          10.1016/j.bmc.2011.11.016
# 6     2015-09-17 17:20:42                       10.1016/0022-1902(67)80090-3
# 7     2015-09-10 13:12:16                       10.1016/j.optcom.2011.05.073
# 8     2015-09-11 08:41:30                               10.1039/JR9590001035
# 9     2015-09-11 20:56:49                         10.1016/j.rser.2015.04.093
# 10    2015-09-04 12:22:46                               10.1021/jacs.5b00504
# ...

# %%
#Como sacar um país da listagem
#data[data["country"] !="China"].groupby("continent").count()
data.groupby("continent").count()
# Out:
#                date   DOI  userID  country  city  DOI_prefix  latitude  \
# continent
# Africa          471   471     471      471   196         471       471
# Asia           3456  3456    3456     3456  2957        3456      3456
# Europe          973   973     973      973   948         973       973
# North America   401   401     401      401   374         401       401
# Oceania           8     8       8        8     8           8         8
# South America   580   580     580      580   574         580       580
#
#                longitude
# continent
# Africa               471
# Asia                3456
# Europe               973
# North America        401
# Oceania                8
# South America        580

# %%
topByCityCountry = data.groupby(["country", "city"]).count().sort_values("date", ascending=False).head(50).date

topByCityCountry.plot("bar", figsize=(30,10), fontsize=(20))

# %%
display(topByCityCountry.sort_values().plot("barh", figsize=(10,20), fontsize=(10)))

# %%
display(topByCityCountry.sort_values().plot("pie", figsize=(20,20), fontsize=(10)))

# %%
data.describe(include= "all")
data[data.continent.isnull() & (~ data.country.isnull())]
#INVERTE o isnull: & (~ data.country.isnull())
# Out:
# Empty DataFrame
# Columns: [date, DOI, userID, country, city, DOI_prefix, latitude, longitude, continent]
# Index: []

# %%
type(data["city"])
# Out:
# pandas.core.series.Series

# %% [markdown]
# ## Importing OA Statuses

# %%
#import df
oa_status_raw00 = pd.read_csv('../data/data_sample/oa_status_sample.csv', index_col=0)

oa_status_raw00.head()
#Boolean Values
# Out:
#                                          doi is_oa  data_standard  \
# 0                     10.1037/e611152013-001     f            1.0
# 1             10.1016/j.braindev.2010.07.004     f            1.0
# 2                10.1016/j.reval.2012.02.143     t            1.0
# 3  10.1093/acprof:oso/9780198159216.003.0020     f            1.0
# 4                      10.1300/j152v07n02_06     f            1.0
#
#                                 best_oa_location_url  \
# 0                                                NaN
# 1                                                NaN
# 2  http://prodinra.inra.fr/ft/CC06E77F-B3EE-4BD2-...
# 3                                                NaN
# 4                                                NaN
#
#   best_oa_location_host_type best_oa_location_version  \
# 0                        NaN                      NaN
# 1                        NaN                      NaN
# 2                 repository         submittedVersion
# ...

# %%
#dropping columns
oa_status00 = oa_status_raw00[["doi","is_oa"]]

# %%
oa_status00 = oa_status00.replace({"is_oa":{"f":False,"t":True}})

# %%
oa_status00.head()
# Out:
#                                          doi  is_oa
# 0                     10.1037/e611152013-001  False
# 1             10.1016/j.braindev.2010.07.004  False
# 2                10.1016/j.reval.2012.02.143   True
# 3  10.1093/acprof:oso/9780198159216.003.0020  False
# 4                      10.1300/j152v07n02_06  False
