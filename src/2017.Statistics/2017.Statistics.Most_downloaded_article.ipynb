# %% [markdown]
# ### The most downloaded articles

# %%
import pandas as pd

# %%
data = pd.read_csv("./../../data/sample/2017.statistics.sample.with_missing_cities.csv")

# %%
data.groupby(["DOI"]).count().sort_values("IPID", ascending=False)
# Out:
#                                     IPID  city  country  date  is_oa  lat  \
# DOI
# 10.1080/01419870.2016.1199889        523   519      519   523    523  519
# 10.1016/j                            103    93      101   103      0   93
# 10.1016/0032-3861(78)90123-4          91    91       91    91     91   91
# 10.1061/(asce)gm.1943-5622.0000048    88    88       88    88     88   88
# 10.1145/954587.954588                 70    70       70    70     70   69
# 10.1021/jp809992g                     66    53       55    66     66   52
# 10.1002/14651858                      62    58       61    62     62   60
# 10.1016/s2214-109x(16)30188-7         57    57       57    57     57   57
# 10.1016/j.joep.2011.02.002            46    46       46    46     46   46
# 10.1016/j.cis.2013.05.005             41    14       41    41     41   23
# 10.1007/bf01096442                    40    40       40    40     40   40
# 10.1158/1538-7445                     39    37       39    39      0   39
# ...

# %%
data.DOI.describe()
# Out:
# count                           1500000
# unique                          1342343
# top       10.1080/01419870.2016.1199889
# freq                                523
# Name: DOI, dtype: object
