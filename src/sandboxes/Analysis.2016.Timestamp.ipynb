# %%
from IPython.display import display

import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

# %%
time = pd.read_table("../data/full/scihub/nov2015.tab", usecols=[0,2],header=None)
#time = pd.read_table("../data/sample/scihub_sample.tab", usecols=[0,2],header=None)

time.columns = ["date", "userID"]

# %%
time["date"] = pd.to_datetime(time["date"], format='%Y-%m-%d %H:%M:%S.%f')

# %%
time = time.set_index("date")

# %%
#time["schedule"] = time["date"].map(lambda x: str(x).split(" ")[0])
#time["schedule"] = pd.to_datetime(time["schedule"], format='%Y-%m-%d')

# %%
#time["clock"] = time["date"].map(lambda x: str(x).split(" ")[-1])
#time["clock"] = pd.to_datetime(time["clock"], format='%H:%M:%S')
#time = time.drop(columns="clock")

# %%
#time = time.drop(columns="date")

# %%
time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1849385 entries, 2015-11-01 00:00:00 to 2015-11-30 23:59:59
# Data columns (total 1 columns):
# userID    object
# dtypes: object(1)
# memory usage: 28.2+ MB

# %%
ploting = time.groupby(time.index.date).count()
ploting
# Out:
#             userID
# 2015-11-01  158860
# 2015-11-02  242674
# 2015-11-03  250108
# 2015-11-04  137325
# 2015-11-22   39967
# 2015-11-23  132895
# 2015-11-24  139344
# 2015-11-25  135707
# 2015-11-26  125278
# 2015-11-27  126436
# 2015-11-28   98349
# 2015-11-29  109454
# 2015-11-30  152988

# %%
ploting.plot(kind="hexbin", x="Index", y="userID", figsize =(30,30), fontsize=(20))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Index'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-113-e076f5a13bbb> in <module>()
# ----> 1 ploting.plot(kind="hexbin", x="Index", y="userID", figsize =(30,30), fontsize=(20))
#
# C:\anaconda\lib\site-packages\pandas\plotting\_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2675                           fontsize=fontsize, colormap=colormap, table=table,
#    2676                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 2677                           sort_columns=sort_columns, **kwds)
#    2678     __call__.__doc__ = plot_frame.__doc__
#    2679
#
# C:\anaconda\lib\site-packages\pandas\plotting\_core.py in plot_frame(data, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    1900                  yerr=yerr, xerr=xerr,
#    1901                  secondary_y=secondary_y, sort_columns=sort_columns,
# -> 1902                  **kwds)
#    1903
#    1904
#
# C:\anaconda\lib\site-packages\pandas\plotting\_core.py in _plot(data, x, y, subplots, ax, kind, **kwds)
#    1685         if isinstance(data, DataFrame):
#    1686             plot_obj = klass(data, x=x, y=y, subplots=subplots, ax=ax,
# -> 1687                              kind=kind, **kwds)
#    1688         else:
#    1689             raise ValueError("plot kind %r can only be used for data frames"
#
# C:\anaconda\lib\site-packages\pandas\plotting\_core.py in __init__(self, data, x, y, C, **kwargs)
#     895
#     896     def __init__(self, data, x, y, C=None, **kwargs):
# --> 897         super(HexBinPlot, self).__init__(data, x, y, **kwargs)
#     898         if is_integer(C) and not self.data.columns.holds_integer():
#     899             C = self.data.columns[C]
#
# C:\anaconda\lib\site-packages\pandas\plotting\_core.py in __init__(self, data, x, y, **kwargs)
#     809         if is_integer(y) and not self.data.columns.holds_integer():
#     810             y = self.data.columns[y]
# --> 811         if len(self.data[x]._get_numeric_data()) == 0:
#     812             raise ValueError(self._kind + ' requires x column to be numeric')
#     813         if len(self.data[y]._get_numeric_data()) == 0:
#
# C:\anaconda\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2137             return self._getitem_multilevel(key)
#    2138         else:
# -> 2139             return self._getitem_column(key)
#    2140
#    2141     def _getitem_column(self, key):
#
# C:\anaconda\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2144         # get column
#    2145         if self.columns.is_unique:
# -> 2146             return self._get_item_cache(key)
#    2147
#    2148         # duplicate columns & possible reduce dimensionality
#
# C:\anaconda\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    1840         res = cache.get(item)
#    1841         if res is None:
# -> 1842             values = self._data.get(item)
#    1843             res = self._box_item_values(item, values)
#    1844             cache[item] = res
#
# C:\anaconda\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    3841
#    3842             if not isna(item):
# -> 3843                 loc = self.items.get_loc(item)
#    3844             else:
#    3845                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# C:\anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
# -> 2527                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2528
#    2529         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Index'

# %%
#time = pd.read_table("../data/full/scihub/nov2015.tab", usecols=[0,2],header=None)
time = pd.read_table("../data/sample/scihub_sample.tab", usecols=[0,2],header=None)

time.columns = ["date", "userID"]

time["date"] = pd.to_datetime(time["date"], format='%Y-%m-%d %H:%M:%S.%f')

bins = pd.date_range(time["date"].min(), time["date"].max(), freq='24h')
time["date"] = pd.cut(time["date"], bins)
time = time.set_index("date")
entries_per_day = time.groupby(time.index).count()
entries_per_day["userID"].plot.bar(figsize=(20,20))

# %% [markdown]
# # SECOND

# %%
scihub_list = ["sep2015.tab", "oct2015.tab", "nov2015.tab", "dec2015.tab", "jan2016.tab", "feb2016.tab"]

# %%
def setdatable(in_path):    
    time = pd.read_table(in_path, usecols=[0,2],header=None)
    time.columns = ["date", "userID"]
    time["schedule"] = time["date"].map(lambda x: str(x).split(" ")[0])
    time["clock"] = time["date"].map(lambda x: str(x).split(" ")[-1])
    time = time.drop(columns="date")
    return time

# %%
#setdatable("../data/sample/","scihub_sample.tab")

# %%
def plotit(in_path):
    ploting = time.groupby(["schedule"]).count()
    ploting.plot(kind="bar", figsize =(30,30), fontsize=(20))
    return ploting

# %%
        
def apply_func(file_list, base_in_path, base_out_path):
    for file in file_list:
        in_path = base_in_path + file
        out_path = base_out_path + file
        setdatable(in_path)
        plotit(in_path)
        plt.savefig(out_path)
        #Export to new directory, full, clean, dataframe.

# %%
apply_func(scihub_list, "./../data/full/scihub/", "./../../" )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-142-dbfcadd8791a> in <module>()
# ----> 1 apply_func(scihub_list, "./../data/full/scihub/", "./../../" )
#
# <ipython-input-141-12dedcbf1c41> in apply_func(file_list, base_in_path, base_out_path)
#       7         setdatable(in_path)
#       8         plotit(in_path)
# ----> 9         plt.savefig(out_path)
#      10         #Export to new directory, full, clean, dataframe.
#      11
#
# C:\anaconda\lib\site-packages\matplotlib\pyplot.py in savefig(*args, **kwargs)
#     699 def savefig(*args, **kwargs):
#     700     fig = gcf()
# --> 701     res = fig.savefig(*args, **kwargs)
#     702     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     703     return res
#
# C:\anaconda\lib\site-packages\matplotlib\figure.py in savefig(self, fname, **kwargs)
#    1832             self.set_frameon(frameon)
#    1833
# -> 1834         self.canvas.print_figure(fname, **kwargs)
#    1835
#    1836         if frameon:
#
# C:\anaconda\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2168
#    2169         # get canvas object and print method for format
# -> 2170         canvas = self._get_output_canvas(format)
#    2171         print_method = getattr(canvas, 'print_%s' % format)
#    2172
#
# C:\anaconda\lib\site-packages\matplotlib\backend_bases.py in _get_output_canvas(self, format)
#    2111         raise ValueError('Format "%s" is not supported.\n'
#    2112                          'Supported formats: '
# -> 2113                          '%s.' % (format, ', '.join(formats)))
#    2114
#    2115     def print_figure(self, filename, dpi=None, facecolor=None, edgecolor=None,
#
# ValueError: Format "tab" is not supported.
# Supported formats: eps, jpeg, jpg, pdf, pgf, png, ps, raw, rgba, svg, svgz, tif, tiff.
