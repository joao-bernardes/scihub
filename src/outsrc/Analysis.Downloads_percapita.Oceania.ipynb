# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Import DataFrame

# %%
world_pop = pd.read_csv("./../../data/outsrc/API_SP.POP.TOTL_DS2_en_csv_v2_10058048.csv")

# %%
world_pop = world_pop.loc[:,("Country Name", "2014")]
world_pop = world_pop.rename({"2014": "2014 Population"}, axis = "columns")
world_pop = world_pop.dropna(how="any")

# %%
world_pop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 262 entries, 0 to 263
# Data columns (total 2 columns):
# Country Name       262 non-null object
# 2014 Population    262 non-null float64
# dtypes: float64(1), object(1)
# memory usage: 6.1+ KB

# %% [markdown]
# ### Import DataFrame

# %%
statistics2017 = pd.read_csv("./../../data/sample/2017.statistics.sample.with_missing_cities_continents.csv")
statistics2017 = statistics2017.loc[:,("DOI","city","country","continent")]
statistics2017 = statistics2017.rename({"DOI": "Downloads"}, axis = "columns")
statistics2017 = statistics2017.groupby(["continent",'country']).count().sort_values(by="Downloads", ascending=False)
statistics2017 = statistics2017.reset_index()
statistics2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 213 entries, 0 to 212
# Data columns (total 4 columns):
# continent    213 non-null object
# country      213 non-null object
# Downloads    213 non-null int64
# city         213 non-null int64
# dtypes: int64(2), object(2)
# memory usage: 6.7+ KB

# %% [markdown]
# ### Merge DataFrame

# %%
statistics2017 = pd.merge(statistics2017, world_pop, left_on="country", right_on="Country Name")
statistics2017 = statistics2017.drop(columns="Country Name")

# %%
statistics2017.head()
# Out:
#        continent        country  Downloads    city  2014 Population
# 0           Asia          China     243363  243250     1.364270e+09
# 1           Asia          India     132886  132886     1.293859e+09
# 2  North America  United States     110440  109912     3.186225e+08
# 3  South America         Brazil      71323   71322     2.042131e+08
# 4           Asia      Indonesia      59517   55160     2.551311e+08

# %%
statistics2017["Downloads_1000hb"] = statistics2017.Downloads / statistics2017["2014 Population"] *1000
statistics2017.head()
# Out:
#        continent        country  Downloads    city  2014 Population  \
# 0           Asia          China     243363  243250     1.364270e+09
# 1           Asia          India     132886  132886     1.293859e+09
# 2  North America  United States     110440  109912     3.186225e+08
# 3  South America         Brazil      71323   71322     2.042131e+08
# 4           Asia      Indonesia      59517   55160     2.551311e+08
#
#    Downloads_1000hb
# 0          0.178383
# 1          0.102705
# 2          0.346617
# 3          0.349258
# 4          0.233280

# %%
a = statistics2017.loc[statistics2017.continent == "Oceania",:].sort_values(by="Downloads_1000hb", ascending=False)

# %%
a.head()
# Out:
#     continent           country  Downloads  city  2014 Population  \
# 116   Oceania     New Caledonia         80    69         268050.0
# 36    Oceania         Australia       6041  5283       23504138.0
# 69    Oceania       New Zealand       1053  1053        4509700.0
# 138   Oceania              Guam         26    26         160967.0
# 137   Oceania  French Polynesia         36    36         275484.0
#
#      Downloads_1000hb
# 116          0.298452
# 36           0.257019
# 69           0.233497
# 138          0.161524
# 137          0.130679

# %%
plot = a.sort_values(by="Downloads_1000hb", ascending=False).head(50)
plt.subplots(figsize=(10, 5))
plot = sns.barplot('country', 'Downloads_1000hb', data=plot)
sns.axes_style('darkgrid')
plt.xticks(rotation=90)
plot.set_ylabel("Nº of Articles per 1000 hab.", fontsize=10)
plot.set_xlabel(" ", fontsize=10)
#plt.title("Fig. 8.1 - Top 50 Countries Requesting Articles | Normalized Values for Population", fontsize=14)
#plt.tight_layout()
#plt.savefig('./../../../charts and figures/'+ "Fig. 8.2 - Downloads.Country.Top50.Norm_Values" + ".pdf")
# Out:
# Text(0.5,0,' ')

# %% [markdown]
# ### What about New Caledonia?

# %%
statistics2017 = pd.read_csv("./../../data/sample/2017.statistics.sample.with_missing_cities.csv")

# %%
new_caledonia = statistics2017.loc[statistics2017.country == "New Caledonia",:]
new_caledonia
# Out:
#                                              DOI      IPID          city  \
# 1754          10.1111/j.1745-6584.1995.tb00023.x     59539        Noumea
# 4822                         10.1021/np50106a013    140337        Noumea
# 8277            10.1111/j.1365-2095.2009.00673.x    229919           NaN
# 26571    10.2136/sssaj1993.03615995005700010039x     61527        Noumea
# 67303                     10.1098/rspb.2002.2218    233405        Noumea
# 74117                  10.1007/s12161-016-0468-8     59539        Noumea
# 76997                     10.1055/s-0034-1389969     61721        Noumea
# 86921                 10.1016/j.admp.2011.12.001    992710        Noumea
# 87597                  10.1007/s12011-007-8005-7   1665381        Noumea
# 93130                            10.2307/1940138   1757124           NaN
# 93218              10.1016/s1773-035x(15)72819-4    992710        Noumea
# 99898                            10.2307/1940628   1863834        Noumea
# 100042                       10.1155/2014/769021    216385        Noumea
# 142677                        10.2188/jea.13.127   2506507        Noumea
# 174450             10.1016/j.scienta.2007.01.028   1415966        Noumea
# 178027       10.1146/annurev-earth-050212-124107    139289        Noumea
# 185161         10.1016/j.aquaculture.2005.10.035   3101163           NaN
# 203414        10.1111/j.1365-3059.1993.tb01479.x   3150733        Noumea
# 214047                 10.1007/s10584-015-1592-y    233405        Noumea
# 214818            10.1146/annurev.genet.30.1.371    233405        Noumea
# 264782                          10.1002/ecy.1709     61527        Noumea
# 290052              10.1097/aci.0b013e32833903a6     61721        Noumea
# 295528                 10.1007/s11258-013-0273-z    139289        Noumea
# 306570                         10.5252/a2012n2a7   1415966        Noumea
# 311486                         10.5252/a2012n2a7   1415966        Noumea
# 315816                    10.1098/rspb.2014.1725     61527        Noumea
# 328137                 10.1007/s00421-016-3497-5     61721        Noumea
# 346020         10.1016/j.smallrumres.2007.12.012   2512456        Noumea
# 377644            10.1144/gsl.mem.1986.011.01.07     59539        Noumea
# 377697                             10.1144/m47.7     59539        Noumea
# ...                                          ...       ...           ...
# 838967                      10.1038/nclimate1887    140244        Noumea
# 846785                      10.2110/jsr.2006.026  10500381         Païta
# 925231              10.1097/brs.0b013e3181c953cc  10110103           NaN
# 925788          10.1097/00007632-200202150-00015  10110103           NaN
# 960841       10.1146/annurev-phyto-082712-102314    310401        Noumea
# 990003                     10.1093/jisesa/iew037  11784621           NaN
# 1003199                  10.1111/2041-210x.12655  11898699        Noumea
# 1015332                  10.1136/emj.2007.052290   8658368        Noumea
# 1029493            10.1016/s0892-6875(00)00140-0   3719798        Noumea
# 1056388                         10.1130/g34483.1     59539        Noumea
# 1082654                10.1007/s12325-015-0267-4  11982197        Noumea
# 1101801             10.1016/j.arabjc.2015.06.018  12862031        Noumea
# 1152950           10.1016/j.jaridenv.2004.07.001  12997531        Noumea
# 1165948         10.1111/j.2042-3306.2010.00133.x  12805936        Noumea
# 1181352                         10.1002/ca.22936   2563351        Noumea
# 1210491             10.1016/0304-3959(87)90100-x  14006249  Le Mont-Dore
# 1235906                10.1007/s11262-016-1356-4    790408        Noumea
# 1266105     10.1001/archderm.1978.01640210028007  13155095           NaN
