# %%
import pandas as pd
import gzip
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#with open("worldcitiespop.txt.gz", encoding=" ISO-8859-1") as f:
pop = pd.read_csv("worldcitiespop.txt.gz", encoding="ISO-8859-1")
# Out:
# C:\anaconda\lib\site-packages\IPython\core\interactiveshell.py:2728: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
pop = pop.dropna(how='any')

# %%
pop.head()
# Out:
#         Country      City AccentCity Region  Population   Latitude   Longitude
# 1544449      jp     tokyo      Tokyo     40  31480498.0  35.685000  139.751389
# 570824       cn  shanghai   Shanghai     23  14608512.0  31.045556  121.399722
# 1327914      in    bombay     Bombay     16  12692717.0  18.975000   72.825833
# 2200161      pk   karachi    Karachi     05  11627378.0  24.905600   67.082200
# 1331162      in     delhi      Delhi      7  10928270.0  28.666667   77.216667

# %%
pop = pop.sort_values(by="Population",ascending=False)

# %%
pop.head()

# %% [markdown]
# ### Import DataFrame

# %%
statistics2017 = pd.read_table("./../../data/sample/2017.statistics.sample.csv", header=None)
#give columns names
statistics2017.columns = ["date", "DOI", "IPID", "userID", "country", "city", "lat", "lon"]

# %%
statistics2017.city = statistics2017["city"].str.lower()

# %%
statistics2017 = statistics2017.loc[:,("DOI","city", "lat", "lon", "userID")]

# %%
#statistics2017 = statistics2017.groupby('city').count().sort_values(by="DOI", ascending=False)

# %%
#statistics2017 = statistics2017.reset_index()

# %%
#We have 19419 different cities requesting to the Sci-Hub
statistics2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1645950 entries, 0 to 1645949
# Data columns (total 5 columns):
# DOI       1645950 non-null object
# city      1383620 non-null object
# lat       1519940 non-null float64
# lon       1519940 non-null float64
# userID    1645950 non-null int64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 62.8+ MB

# %%
statistics2017 = pd.merge(statistics2017, pop, how='inner', on=['lat', 'lon'])

# %%
statistics2017.head()
# Out:
#                                 DOI   city      lat       lon   userID  \
# 0   10.1148/radiology.193.1.8090902  seoul  37.5985  126.9783  4162400
# 1                10.1039/c5cs00585j  seoul  37.5985  126.9783  1008430
# 2  10.1053/j.seminoncol.2016.02.013  seoul  37.5985  126.9783  1973093
# 3          10.1177/0271678x17701156  seoul  37.5985  126.9783  6676741
# 4         10.1007/s10494-011-9367-7  seoul  37.5985  126.9783  3819776
#
#   Country   City AccentCity Region  Population
# 0      kr  seoul      Seoul     11  10323448.0
# 1      kr  seoul      Seoul     11  10323448.0
# 2      kr  seoul      Seoul     11  10323448.0
# 3      kr  seoul      Seoul     11  10323448.0
# 4      kr  seoul      Seoul     11  10323448.0

# %%
statistics2017 = statistics2017.groupby('city').count().sort_values(by="DOI", ascending=False)

# %%
statistics2017["norm_values"] = statistics2017.DOI / statistics2017.Population

# %%
statistics2017
# Out:
#             DOI  lat  lon  userID  Country  City  AccentCity  Region  \
# city
# seoul       450  450  450     450      450   450         450     450
# honolulu    136  136  136     136      136   136         136     136
# anchorage    14   14   14      14       14    14          14      14
# pearl city   13   13   13      13       13    13          13      13
# waipahu      13   13   13      13       13    13          13      13
# kailua        8    8    8       8        8     8           8       8
# fairbanks     6    6    6       6        6     6           6       6
# wailuku       4    4    4       4        4     4           4       4
# ketchikan     2    2    2       2        2     2           2       2
# wasilla       2    2    2       2        2     2           2       2
# bănești       1    1    1       1        1     1           1       1
# juneau        1    1    1       1        1     1           1       1
# lahaina       1    1    1       1        1     1           1       1
#
#             Population  norm_values
# city
# seoul              450          1.0
# honolulu           136          1.0
# anchorage           14          1.0
# pearl city          13          1.0
# waipahu             13          1.0
# kailua               8          1.0
# fairbanks            6          1.0
# wailuku              4          1.0
# ketchikan            2          1.0
# wasilla              2          1.0
# bănești              1          1.0
# juneau               1          1.0
# lahaina              1          1.0

# %%
a = statistics2017.sort_values(by="norm_values", ascending=False).head(25)

# %%
plt.subplots(figsize=(10, 5))
plt.xticks(rotation=90)
plot = sns.barplot("City","norm_values", data=a)

plt.title("Fig. 7.1 - Top Cities Requesting Articles | Normalized Values for Population")
plt.tight_layout()
#plt.savefig("./../../charts and figures/Fig. 7.1 - Articles.City.Top25.Norm_Values.pdf")

# %%
plot = a.plot.bar(x=["Country","city"],y="norm_values", fontsize=20, figsize=(20,10))
plt.title("Fig. 7.1 - Top Cities Requesting Articles | Normalized Values for Population")
plt.tight_layout()
#plt.savefig("./../../charts and figures/Fig. 7.1 - Articles.City.Top25.Norm_Values.pdf")

# %%
scatter =statistics2017.sort_values(by="norm_values", ascending=False)
scatter.plot.scatter(x="Population",y="DOI")

# %%
scatter =statistics2017.sort_values(by="norm_values", ascending=False)
scatter.plot.scatter(x="norm_values",y="DOI")

# %%
geonames = pd.read_table("./../../data/GeoNames/cities1000.zip", header = None)
geonames.columns = ["geonameID", "name", "asciiname", "alternatenames", "latitude", "longitude", "feature class", "feature code", "country code", "cc2", "admin1 code", "admin2 code", "admin3 code", "admin4 code", "population", "elevation", "dem", "timezone", "modification date"]
# Out:
# C:\anaconda\lib\site-packages\IPython\core\interactiveshell.py:2728: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
geonames
# Out:
#         geonameID                 name            asciiname  \
# 0         3039154            El Tarter            El Tarter
# 1         3039163  Sant Julià de Lòria  Sant Julia de Loria
# 2         3039604       Pas de la Casa       Pas de la Casa
# 3         3039678               Ordino               Ordino
# 4         3040051         les Escaldes         les Escaldes
# 5         3040132           la Massana           la Massana
# 6         3040686               Encamp               Encamp
# 7         3041204              Canillo              Canillo
# 8         3041519              Arinsal              Arinsal
# 9         3041563     Andorra la Vella     Andorra la Vella
# 10         290594       Umm al Qaywayn       Umm al Qaywayn
# 11         291074       Ras al-Khaimah       Ras al-Khaimah
# 12         291279             Muzayri‘             Muzayri`
# 13         291696         Khawr Fakkān         Khawr Fakkan
# 14         292223                Dubai                Dubai
# 15         292231    Dibba Al-Fujairah    Dibba Al-Fujairah
# 16         292239        Dibba Al-Hisn        Dibba Al-Hisn
# 17         292672              Sharjah              Sharjah
# 18         292688            Ar Ruways            Ar Ruways
# 19         292878          Al Fujayrah          Al Fujayrah
# 20         292913               Al Ain               Al Ain
# 21         292932                Ajman                Ajman
# 22         292953            Adh Dhayd            Adh Dhayd
# 23         292968            Abu Dhabi            Abu Dhabi
# 24        1120471               Zorkot               Zorkot
# 25        1120473     Wulêswālī Bihsūd     Wuleswali Bihsud
# 26        1120483               Kuhsān               Kuhsan
# 27        1120484                 Lāsh                 Lash
# 28        1120487               Tukzār               Tukzar
# 29        1120500                Mīray                Miray
# ...           ...                  ...                  ...
# 127629     889795               Insiza               Insiza
# 127630     889942               Hwange               Hwange
# 127631     890242            Headlands            Headlands
# 127632     890299               Harare               Harare
# 127633     890422                Gweru                Gweru
# 127634     890516               Gwanda               Gwanda
# 127635     890983                Gokwe                Gokwe
# 127636     891099             Glendale             Glendale
# 127637     891515             Filabusi             Filabusi
# 127638     891699            Esigodini            Esigodini
# 127639     892156  Dorowa Mining Lease  Dorowa Mining Lease
# 127640     892440                 Dete                 Dete
# 127641     892876           Concession           Concession
# 127642     893172               Chivhu               Chivhu
# 127643     893397             Chirundu             Chirundu
# 127644     893485             Chiredzi             Chiredzi
# 127645     893549             Chipinge             Chipinge
# 127646     893697             Chinhoyi             Chinhoyi
# 127647     893813          Chimanimani          Chimanimani
# 127648     894239              Chegutu              Chegutu
# 127649     894413              Chakari              Chakari
# 127650     894460            Centenary            Centenary
# 127651     894701             Bulawayo             Bulawayo
# 127652     895057                Binga                Binga
# 127653     895061              Bindura              Bindura
# 127654     895269           Beitbridge           Beitbridge
# 127655     895308             Beatrice             Beatrice
# 127656     895417               Banket               Banket
# 127657    1085510              Epworth              Epworth
# 127658    1106542          Chitungwiza          Chitungwiza
#
#                                            alternatenames  latitude  \
# 0                                    Ehl Tarter,Эл Тартер  42.57952
# 1       San Julia,San Julià,Sant Julia de Loria,Sant J...  42.46372
# 2                           Pas de la Kasa,Пас де ла Каса  42.54277
# 3       Ordino,ao er di nuo,orudino jiao qu,Ордино,オルデ...  42.55623
# 4       Ehskal'des-Ehndzhordani,Escaldes,Escaldes-Engo...  42.50729
# 5       La Macana,La Massana,La Maçana,La-Massana,la M...  42.54499
# 6       Ehnkam,Encamp,en kan pu,enkanpu jiao qu,Энкам,...  42.53474
# 7       Canillo,Kanil'o,ka ni e,kaniryo jiao qu,Каниль...  42.56760
# 8       Arinsal,Arinsal',Arinsalis,arynsal,Аринсал,Ари...  42.57205
# 9       ALV,Ando-la-Vyey,Andora,Andora la Vela,Andora ...  42.50779
# 10      Oumm al Qaiwain,Oumm al Qaïwaïn,Um al Kawain,U...  25.56473
# 11      Julfa,Khaimah,RKT,Ra's al Khaymah,Ra's al-Chai...  25.78953
# 12      Mezaira'a,Mezaira’a,Mizeir`ah,Mizeir‘ah,Mozayr...  23.14355
# 13      Fakkan,Fakkān,Khawr Fakkan,Khawr Fakkān,Khawr ...  25.33132
# 14      DXB,Dabei,Dibai,Dibay,Doubayi,Dubae,Dubai,Duba...  25.06570
# 15      Al-Fujairah,BYB,Dibba Al-Fujairah,dba alfjyrt,...  25.59246
# 16      BYB,Daba,Daba al-Hisn,Dabā,Dabā al-Ḥiṣn,Diba,D...  25.61955
# 17      Al Sharjah,Ash 'Mariqah,Ash Shariqa,Ash Shariq...  25.33737
# 18      Ar Ru'ays,Ar Ruways,Ar Ru’ays,Ar-Ruvais,Ruwais...  24.11028
# 19      Al Fujayrah,Al-Fudjayra,Al-Fujayrah' emiraat,F...  25.11641
# 20      AAN,Ainas,Al Ain,Al Ajn,Al Ayn,Al `Ayn,Al Ɛayn...  24.19167
# 21                   Ajman,Al Ajman,QAJ,Ujman,ʿjman,عجمان  25.41111
# 22      Adh Dhaid,Adh Dhayd,Al Daid,Al-Dhayd,Dayd,Dhai...  25.28812
# 23      A-pu-that-pi,AEbu Saby,AUH,Aboe Dhabi,Abou Dab...  24.46667
# 24      Vulusvali-Zorkot,Woludwali Zorkot,Woludwālī Zō...  33.54149
# 25      Behsud,Behsūd,Markaz-e Bihsud,Markaz-e Bihsūd,...  34.34360
# 26      Kohistan,Kohsan,Kohsān,Koshan,Kuhestan,Kuhsan,...  34.65389
# 27      Kohestan,Kohestān,Laorlash,Laorlush,Las,Lash,L...  35.37820
# 28      Kala Sangcharak,Kala Sangchārak,Qal`eh Sangcha...  35.94831
# 29      Miray,Miri,Miṟay,Mīray,Mīrī,Salgar,Shalgar,S̄a...  33.32462
# ...                                                   ...       ...
# 127629                                                NaN -19.78333
# 127630  Hvange,Hvangė,Khvange,WKI,Wange,Wankie,hwang-g... -18.36446
# 127631                                          Headlands -18.27733
# 127632  Arare,Charare,Gorad Kharareh,HRE,Harare,Harare... -17.82772
# 127633                        GWE,Gveru,Gwelo,Gweru,Гверу -19.45000
# 127634            Gvanda,Jawunda,guan da,Гванда,گوانڈا,關達 -20.93333
# 127635                                              Gokwe -18.20476
# 127636                                           Glendale -17.35514
# 127637                                Emfelabuso,Filabusi -20.53333
# 127638                                Esigodini,Essexvale -20.28979
# 127639           Dorowa,Dorowa Claims,Dorowa Mining Lease -19.06667
# 127640                                          Dete,Dett -18.61667
# 127641                                         Concession -17.38333
# 127642                                  Chivhu,Enkeldoorn -19.02112
# 127643  Chirunda,Chirundo,Chirundu,Chirundu Township,O... -16.03333
# 127644                                       BFO,Chiredzi -21.05000
# 127645                              CHJ,Chipinga,Chipinge -20.18833
# 127646  Chinhoyi,Chinkhoi,Chinkhoji,Chinoyi,Cinhojis,S... -17.36667
# 127647                Chimanimani,Mandidzudzure,Melsetter -19.80000
# 127648                Cheguto,Chegutu,Hartley,New Hartley -18.13021
# 127649                                    Chakari,Shagari -18.06294
# 127650                                          Centenary -16.72289
# 127651  BUQ,Bulavajas,Bulavajo,Bulavejo,Bulawayo,Gorad... -20.15000
# 127652                                              Binga -17.62027
# 127653       Bindura,Bindura Town,Kimberley Reefs,Биндура -17.30192
# 127654  Bajtbridz,Bajtbridzh,Beitbridge,Beitbridzas,Be... -22.21667
# 127655                                                NaN -18.25283
# 127656                             Banket,Banket Junction -17.38333
# 127657                                            Epworth -17.89000
# 127658  Chitungviza,Chitungwiza,Citungviza,Gorad Chytu... -18.01274
#
#         longitude feature class feature code country code  cc2 admin1 code  \
# 0         1.65362             P          PPL           AD  NaN          02
# 1         1.49129             P         PPLA           AD  NaN          06
# 2         1.73361             P          PPL           AD  NaN          03
# 3         1.53319             P         PPLA           AD  NaN          05
# 4         1.53414             P         PPLA           AD  NaN          08
# 5         1.51483             P         PPLA           AD  NaN          04
# 6         1.58014             P         PPLA           AD  NaN          03
# 7         1.59756             P         PPLA           AD  NaN          02
# 8         1.48453             P          PPL           AD  NaN          04
# 9         1.52109             P         PPLC           AD  NaN          07
# 10       55.55517             P         PPLA           AE  NaN          07
# 11       55.94320             P         PPLA           AE  NaN          05
# 12       53.78810             P          PPL           AE  NaN          01
# 13       56.34199             P          PPL           AE  NaN          06
# 14       55.17128             P         PPLA           AE  NaN          03
# 15       56.26176             P          PPL           AE  NaN          04
# 16       56.27291             P          PPL           AE  NaN          04
# 17       55.41206             P         PPLA           AE  NaN          06
# 18       52.73056             P          PPL           AE   AE          01
# 19       56.34141             P         PPLA           AE  NaN          04
# 20       55.76056             P          PPL           AE  NaN          01
# 21       55.43504             P         PPLA           AE  NaN          02
# 22       55.88157             P          PPL           AE  NaN          06
# 23       54.36667             P         PPLC           AE  NaN          01
# 24       69.73446             P        PPLA2           AF  NaN          37
# 25       67.90567             P        PPLA2           AF  NaN          27
# 26       61.19778             P        PPLA2           AF  NaN          11
# 27       64.77457             P        PPLA2           AF  NaN          07
# 28       66.42132             P        PPLA2           AF  NaN          33
# 29       68.44068             P        PPLA2           AF  NaN          08
# ...           ...           ...          ...          ...  ...         ...
# 127629   29.20000             P          PPL           ZW  NaN          07
# 127630   26.49877             P          PPL           ZW  NaN          06
# 127631   32.05150             P          PPL           ZW  NaN          01
# 127632   31.05337             P         PPLC           ZW  NaN          10
# 127633   29.81667             P         PPLA           ZW  NaN          02
# 127634   29.00000             P         PPLA           ZW  NaN          07
# 127635   28.93490             P          PPL           ZW  NaN          02
# 127636   31.06718             P          PPL           ZW  NaN          03
# 127637   29.28502             P          PPL           ZW  NaN          07
# 127638   28.92261             P          PPL           ZW  NaN          07
# 127639   31.75000             P          PPL           ZW  NaN          01
# 127640   26.86667             P          PPL           ZW  NaN          06
# 127641   30.95000             P          PPL           ZW  NaN          03
# 127642   30.89218             P          PPL           ZW  NaN          04
# 127643   28.85000             P          PPL           ZW  NaN          05
# 127644   31.66667             P          PPL           ZW  NaN          08
# 127645   32.62365             P          PPL           ZW  NaN          01
# 127646   30.20000             P         PPLA           ZW  NaN          05
# 127647   32.86667             P          PPL           ZW  NaN          01
# 127648   30.14074             P          PPL           ZW  NaN          05
# 127649   29.89246             P          PPL           ZW  NaN          05
# 127650   31.11462             P          PPL           ZW  NaN          03
# 127651   28.58333             P         PPLA           ZW  NaN          09
# 127652   27.34139             P          PPL           ZW  NaN          06
# 127653   31.33056             P         PPLA           ZW  NaN          03
# 127654   30.00000             P          PPL           ZW  NaN          07
# 127655   30.84730             P          PPL           ZW  NaN          04
# 127656   30.40000             P          PPL           ZW  NaN          05
# 127657   31.14750             P         PPLX           ZW  NaN          10
# 127658   31.07555             P          PPL           ZW  NaN          10
#
#        admin2 code admin3 code admin4 code  population  elevation   dem  \
# 0              NaN         NaN         NaN        1052        NaN  1721
# 1              NaN         NaN         NaN        8022        NaN   921
# 2              NaN         NaN         NaN        2363     2050.0  2106
# 3              NaN         NaN         NaN        3066        NaN  1296
# 4              NaN         NaN         NaN       15853        NaN  1033
# 5              NaN         NaN         NaN        7211        NaN  1245
# 6              NaN         NaN         NaN       11223        NaN  1257
# 7              NaN         NaN         NaN        3292        NaN  1561
# 8              NaN         NaN         NaN        1419        NaN  1465
# 9              NaN         NaN         NaN       20430        NaN  1037
# 10             NaN         NaN         NaN       44411        NaN     2
# 11             NaN         NaN         NaN      115949        NaN     2
# 12             NaN         NaN         NaN       10000        NaN   123
# 13             NaN         NaN         NaN       33575        NaN    20
# 14             NaN         NaN         NaN     1137347        NaN     3
# 15             NaN         NaN         NaN       30000        NaN    16
# 16             NaN         NaN         NaN       26395        NaN     4
# 17             NaN         NaN         NaN      543733        NaN     6
# 18             NaN         NaN         NaN       16000        NaN    16
# 19             NaN         NaN         NaN       62415        NaN    15
# 20             NaN         NaN         NaN      408733        NaN   275
# 21             NaN         NaN         NaN      226172        NaN     4
# 22             NaN         NaN         NaN       24716        NaN   114
# 23             NaN         NaN         NaN      603492        NaN     6
# 24            3205         NaN         NaN           0        NaN  1845
# 25             404         NaN         NaN           0        NaN  2960
# 26            2008         NaN         NaN       12087        NaN   740
# 27            1805         NaN         NaN           0        NaN  1927
# 28            3102         NaN         NaN       12021        NaN  1210
# 29             614         NaN         NaN           0        NaN  2077
# ...            ...         ...         ...         ...        ...   ...
# 127629         NaN         NaN         NaN        2645        NaN  1422
# 127630      889941         NaN         NaN       33210        NaN   767
# 127631         NaN         NaN         NaN        1728        NaN  1563
# 127632         NaN         NaN         NaN     1542813        NaN  1494
# 127633         NaN         NaN         NaN      146073        NaN  1412
# 127634         NaN         NaN         NaN       14450        NaN   982
# 127635         NaN         NaN         NaN       18942        NaN  1237
# 127636         NaN         NaN         NaN        9768        NaN  1143
# 127637         NaN         NaN         NaN        1756        NaN  1072
# 127638         NaN         NaN         NaN        2228        NaN  1181
# 127639         NaN         NaN         NaN        1676        NaN   916
# 127640         NaN         NaN         NaN        2993        NaN  1112
# 127641         NaN         NaN         NaN        4983        NaN  1331
# 127642         NaN         NaN         NaN       10369        NaN  1450
# 127643         NaN         NaN         NaN        1911        NaN   402
# 127644         NaN         NaN         NaN       28205        NaN   436
# 127645         NaN         NaN         NaN       18860        NaN  1109
# 127646         NaN         NaN         NaN       61739        NaN  1153
# 127647         NaN         NaN         NaN        2752        NaN  1565
# 127648         NaN         NaN         NaN       47294        NaN  1187
# 127649         NaN         NaN         NaN        6472        NaN  1107
# 127650         NaN         NaN         NaN        3388        NaN  1186
# 127651         NaN         NaN         NaN      699385        NaN  1348
# 127652         NaN         NaN         NaN        4327        NaN   628
# 127653         NaN         NaN         NaN       37423        NaN  1118
# 127654         NaN         NaN         NaN       26459        NaN   461
# 127655         NaN         NaN         NaN        1647        NaN  1307
# 127656         NaN         NaN         NaN        9641        NaN  1277
# 127657         NaN         NaN         NaN      123250        NaN  1508
# 127658         NaN         NaN         NaN      340360        NaN  1435
#
#               timezone modification date
# 0       Europe/Andorra        2012-11-03
# 1       Europe/Andorra        2013-11-23
# 2       Europe/Andorra        2008-06-09
# 3       Europe/Andorra        2009-12-11
# 4       Europe/Andorra        2008-10-15
# 5       Europe/Andorra        2008-10-15
# 6       Europe/Andorra        2012-04-13
# 7       Europe/Andorra        2012-12-24
# 8       Europe/Andorra        2010-01-29
# 9       Europe/Andorra        2010-05-30
# 10          Asia/Dubai        2014-10-07
# 11          Asia/Dubai        2015-12-05
# 12          Asia/Dubai        2013-10-24
# 13          Asia/Dubai        2013-10-25
# 14          Asia/Dubai        2014-12-02
# 15          Asia/Dubai        2014-08-12
# 16          Asia/Dubai        2014-04-21
# 17          Asia/Dubai        2013-03-05
# 18          Asia/Dubai        2012-11-03
# 19          Asia/Dubai        2016-12-18
# 20          Asia/Dubai        2013-03-17
# 21          Asia/Dubai        2013-03-24
# 22          Asia/Dubai        2012-01-18
# 23          Asia/Dubai        2016-06-03
# 24          Asia/Kabul        2018-02-17
# 25          Asia/Kabul        2018-02-17
# 26          Asia/Kabul        2018-02-17
# 27          Asia/Kabul        2018-02-17
# 28          Asia/Kabul        2018-02-17
# 29          Asia/Kabul        2018-02-17
# ...                ...               ...
# 127629   Africa/Harare        2013-03-12
# 127630   Africa/Harare        2014-11-16
# 127631   Africa/Harare        2012-01-17
# 127632   Africa/Harare        2015-06-03
# 127633   Africa/Harare        2009-06-30
# 127634   Africa/Harare        2009-06-30
# 127635   Africa/Harare        2012-05-05
# 127636   Africa/Harare        2012-01-17
# 127637   Africa/Harare        2012-01-17
# 127638   Africa/Harare        2012-01-17
# 127639   Africa/Harare        2018-02-21
# 127640   Africa/Harare        2013-03-12
# 127641   Africa/Harare        2013-03-12
# 127642   Africa/Harare        2018-04-06
# 127643   Africa/Harare        2018-02-21
# 127644   Africa/Harare        2013-05-08
# 127645   Africa/Harare        2015-04-24
# 127646   Africa/Harare        2009-06-30
# 127647   Africa/Harare        2013-03-12
# 127648   Africa/Harare        2012-01-17
# 127649   Africa/Harare        2012-01-17
# 127650   Africa/Harare        2012-01-17
# 127651   Africa/Harare        2010-08-03
# 127652   Africa/Harare        2012-01-17
# 127653   Africa/Harare        2010-08-03
# 127654   Africa/Harare        2013-03-12
# 127655   Africa/Harare        2018-04-06
# 127656   Africa/Harare        2013-03-12
# 127657   Africa/Harare        2012-01-19
# 127658   Africa/Harare        2012-01-20
#
# [127659 rows x 19 columns]

# %%
geonames.loc[geonames.name == "Buenos Aires",:]
# Out:
#        geonameID          name     asciiname  \
# 1327     3435910  Buenos Aires  Buenos Aires
# 15990    3688357  Buenos Aires  Buenos Aires
# 16259    3624593  Buenos Aires  Buenos Aires
# 49096    3614583  Buenos Aires  Buenos Aires
# 74993    4016589  Buenos Aires  Buenos Aires
# 75329    8858162  Buenos Aires  Buenos Aires
# 76018    8858858  Buenos Aires  Buenos Aires
# 76059    8858899  Buenos Aires  Buenos Aires
# 78458    3620603  Buenos Aires  Buenos Aires
# 81171    3713678  Buenos Aires  Buenos Aires
# 81172    3713682  Buenos Aires  Buenos Aires
# 81701    3699217  Buenos Aires  Buenos Aires
# 81702    3699223  Buenos Aires  Buenos Aires
# 81746    3763294  Buenos Aires  Buenos Aires
# 82552    6559994  Buenos Aires  Buenos Aires
#
#                                           alternatenames  latitude  longitude  \
# 1327   BUE,Baires,Bonaero,Bonaeropolis,Bonaëropolis,B... -34.61315  -58.37723
# 15990                                                NaN   3.01397  -76.64612
# 16259                                   BAI,Buenos Aires   9.17189  -83.33417
# 49096                                                NaN  15.03333  -88.96667
# 74993                                       Buenos Aires  19.07499 -102.17999
# 75329                                       Buenos Aires  18.02444 -102.28583
# 76018                                       Buenos Aires  32.42278 -116.94111
# 76059                                       Buenos Aires  20.15333  -97.74833
# 78458                                       Buenos Aires  11.46916  -85.81661
# 81171                                       Buenos Aires   8.63146  -79.94775
# 81172                                       Buenos Aires   8.41384  -81.48440
# 81701                                                NaN  -8.13861  -79.04028
# 81702                 Buenos Aires,Buenos Aires Hacienda  -5.26083  -79.96417
# 81746                                                NaN  -6.79111  -76.32639
# 82552                                                NaN  -9.12417  -78.49750
#
#       feature class feature code country code  cc2 admin1 code admin2 code  \
# 1327              P         PPLC           AR  NaN          07         NaN
# 15990             P          PPL           CO  NaN          09       19110
# 16259             P          PPL           CR  NaN          07         603
# 49096             P          PPL           HN  NaN          05         NaN
# 74993             P          PPL           MX  NaN          16         064
# 75329             P          PPL           MX  NaN          16         052
# 76018             P          PPL           MX  NaN          02         004
# 76059             P          PPL           MX  NaN          21         089
# 78458             P          PPL           NI  NaN          15         NaN
# 81171             P        PPLA3           PA  NaN          13         NaN
# 81172             P        PPLA2           PA  NaN          12         NaN
# 81701             P        PPLA3           PE  NaN          13        1301
# 81702             P        PPLA3           PE  NaN          20        2004
# 81746             P        PPLA3           PE  NaN          22        2207
# 82552             P        PPLA3           PE  NaN          02        0218
#
#       admin3 code admin4 code  population  elevation   dem  \
# 1327          NaN         NaN    13076300        NaN    31
# 15990         NaN         NaN        2144        NaN  1200
# 16259       60301         NaN       11680        NaN   361
# 49096         NaN         NaN        1131        NaN   956
# 74993         NaN         NaN       10707        NaN   481
# 75329         NaN         NaN        9868        NaN    63
# 76018         NaN         NaN        1761        NaN   222
# 76059         NaN         NaN        1711        NaN   585
# 78458         NaN         NaN        1692        NaN    60
# 81171         NaN         NaN         496        NaN   232
# 81172         NaN         NaN         400        NaN   336
# 81701      130111         NaN           0        NaN    13
# 81702      200402         NaN        7932        NaN   154
# 81746      220702         NaN           0        NaN   213
# 82552      021809         NaN           0        NaN    73
#
#                              timezone modification date
# 1327   America/Argentina/Buenos_Aires        2017-05-28
# 15990                  America/Bogota        2018-04-22
# 16259              America/Costa_Rica        2016-09-07
# 49096             America/Tegucigalpa        2006-01-17
# 74993             America/Mexico_City        2015-06-22
# 75329             America/Mexico_City        2014-04-11
# 76018                 America/Tijuana        2014-04-11
# 76059             America/Mexico_City        2014-04-11
# 78458                 America/Managua        2012-02-02
# 81171                  America/Panama        2017-08-16
# 81172                  America/Panama        2017-08-16
# 81701                    America/Lima        2012-07-19
# 81702                    America/Lima        2012-07-19
# 81746                    America/Lima        2012-07-19
# 82552                    America/Lima        2012-07-19

# %%
country_code = pd.read_csv("https://raw.githubusercontent.com/lukes/ISO-3166-Countries-with-Regional-Codes/master/all/all.csv", usecols=("name","alpha-2"))

# %%
geonames = pd.merge(geonames, country_code,left_on='country code', right_on='alpha-2')

# %%
geonames = geonames.loc[:,("asciiname", "name", "population")]
# Out:
# C:\anaconda\lib\site-packages\pandas\core\indexing.py:858: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_lowerdim(tup)

# %%
geonames.head()
# Out:
#              asciiname  name  population
# 0            El Tarter   NaN        1052
# 1  Sant Julia de Loria   NaN        8022
# 2       Pas de la Casa   NaN        2363
# 3               Ordino   NaN        3066
# 4         les Escaldes   NaN       15853

# %%
statistics2017 = pd.read_table("./../../data/sample/2017.statistics.sample.csv", header=None)
#give columns names
statistics2017.columns = ["date", "DOI", "IPID", "userID", "country", "city", "lat", "lon"]

# %%
statistics2017 = statistics2017.loc[:,("DOI", "country", "city")]
