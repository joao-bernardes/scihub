# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
rand = pd.read_csv('./API_GB.XPD.RSDV.GD.ZS_DS2_en_csv_v2_9944937.csv')

# %%
df = rand.loc[:,("Country Name","2009")]

df = df.dropna()

# %%
statistics2017 = pd.read_table("./../../../data/sample/2017.statistics.sample.csv", header=None)
#give columns names
statistics2017.columns = ["date", "DOI", "IPID", "userID", "country", "city", "lat", "lon"]

# %%
statistics2017 = statistics2017.loc[:,("DOI","country")]

statistics2017 = statistics2017.groupby('country').count().sort_values(by="DOI", ascending=False)

statistics2017 = statistics2017.reset_index()

# %%
plot = pd.merge(statistics2017, df, left_on="country", right_on="Country Name")

plot["norm_values"] = plot.DOI / plot["2009"]

plot.head()
# Out:
#          country     DOI   Country Name     2009    norm_values
# 0          China  272406          China  1.66249  163854.218672
# 1          India  142436          India  0.84461  168641.147985
# 2  United States  131295  United States  2.82226   46521.227669
# 3         Brazil   76880         Brazil  1.11968   68662.474993
# 4      Indonesia   58703      Indonesia  0.08327  704971.778552

# %%
plt.subplots(figsize=(30,30))
ax = sns.regplot(x="2009", y="DOI", data=plot)

def label_point(x, y, val, ax):
    a = pd.concat({'x': x, 'y': y, 'val': val}, axis=1)
    for i, point in a.iterrows():
        ax.text(point['x']+.02, point['y'], str(point['val']))

label_point(plot["2009"], plot.DOI, plot.country, plt.gca())

# %%
df = rand.loc[:,("Country Name","2015")]

df = df.dropna()

# %%
plot = pd.merge(statistics2017, df, left_on="country", right_on="Country Name")

plot["norm_values"] = plot.DOI / plot["2015"]

plot.head()
# Out:
#          country     DOI   Country Name     2015    norm_values
# 0          China  272406          China  2.06558  131878.697509
# 1          India  142436          India  0.62740  227025.820848
# 2  United States  131295  United States  2.79385   46994.291032
# 3         France   45800         France  2.23135   20525.690725
# 4         Mexico   35465         Mexico  0.55238   64203.990007

# %%
plt.subplots(figsize=(30,30))
ax = sns.regplot(x="2015", y="DOI", data=plot)

def label_point(x, y, val, ax):
    a = pd.concat({'x': x, 'y': y, 'val': val}, axis=1)
    for i, point in a.iterrows():
        ax.text(point['x']+.02, point['y'], str(point['val']))

label_point(plot["2015"], plot.DOI, plot.country, plt.gca())

# %%
plt.subplots(figsize=(30,30))
ax = sns.regplot(x="2015", y="norm_values", data=plot)

def label_point(x, y, val, ax):
    a = pd.concat({'x': x, 'y': y, 'val': val}, axis=1)
    for i, point in a.iterrows():
        ax.text(point['x']+.02, point['y'], str(point['val']))

label_point(plot["2015"], plot.norm_values, plot.country, plt.gca())

# %%
plot["2015"].corr(plot.DOI)
# Out:
# 0.21363030772041866

# %%
plot["2015"].corr(plot.norm_values)
# Out:
# -0.11618775177737838
