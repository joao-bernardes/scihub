# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Import DataFrame

# %%
statistics2017 = pd.read_csv("./../../data/sample/2017.statistics.sample.with_missing_cities_continents.csv")
statistics2017 = statistics2017.rename({"DOI": "Downloads"}, axis = "columns")
statistics2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500000 entries, 0 to 1499999
# Data columns (total 11 columns):
# Downloads     1500000 non-null object
# IPID          1500000 non-null int64
# city          1394066 non-null object
# country       1468489 non-null object
# date          1500000 non-null object
# is_oa         1480851 non-null object
# lat           1386787 non-null float64
# lon           1386787 non-null float64
# userID        1500000 non-null int64
# continent     1467987 non-null object
# DOI_prefix    1500000 non-null float64
# dtypes: float64(3), int64(2), object(6)
# memory usage: 125.9+ MB

# %%
country_list = ["Mexico","Cuba","Dominican Republic","Haiti","Guadeloupe","Martinique", "Saint-Barthélemy",
                "Puerto Rico","Belize","Costa Rica","El Salvador","Guatemala","Honduras","Nicaragua","Panama"]

# %%
list_1 = [statistics2017.loc[statistics2017.continent == "North America"].country.unique()]
list_2 = country_list
N_list = np.setdiff1d(list_1,list_2)

# %%
N = statistics2017.loc[statistics2017.continent == "Europe",:]
for i in N_list:
    N2 = statistics2017.loc[statistics2017.country == i,:]
    N = N.append(N2)

# %%
N = N.drop_duplicates()

# %%
plot1 = N.groupby("country").count().sort_values("date", ascending=False).head(10).Downloads

# %%
table1 = N.loc[:,("country","city","Downloads")].groupby(['country']).count().sort_values(by='Downloads',ascending = False).head(15)
table1 = table1.loc[:,"Downloads"]
print(table1.to_latex())
# Out:
# \begin{tabular}{lr}
# \toprule
# {} &  Downloads \\
# country        &            \\
# \midrule
# United States  &     110440 \\
# France         &      40649 \\
# Spain          &      30446 \\
# United Kingdom &      28376 \\
# Germany        &      27907 \\
# Italy          &      25692 \\
# Canada         &      25237 \\
# Netherlands    &      20280 \\
# Portugal       &      16859 \\
# Greece         &      10513 \\
# Poland         &      10356 \\
# Romania        &      10138 \\
# Switzerland    &       7595 \\
# Ukraine        &       7582 \\
# Belgium        &       7374 \\
# \bottomrule
# \end{tabular}

# %%
table2 = N.loc[:,("country","city","Downloads")].groupby(['country','city']).count().sort_values(by='Downloads',ascending = False).head(15)
table2
# Out:
#                                 Downloads
# country        city
# France         Paris                16248
# United Kingdom London               15684
# Netherlands    Amsterdam            13971
# Canada         Toronto              13563
# United States  Los Angeles           8962
# Spain          Madrid                8665
# Greece         Athina                7379
# Portugal       Lisboa                6946
# United States  Chicago               6735
# Germany        Haina (Kloster)       5973
# United States  San Jose              5427
#                Wilmington            5403
#                Buffalo               5038
# Spain          Barcelona             4854
# United States  Potwin                4643

# %%
print (table2.to_latex())
# Out:
# \begin{tabular}{llr}
# \toprule
#               &        &  Downloads \\
# country & city &            \\
# \midrule
# France & Paris &      16248 \\
# United Kingdom & London &      15684 \\
# Netherlands & Amsterdam &      13971 \\
# Canada & Toronto &      13563 \\
# United States & Los Angeles &       8962 \\
# Spain & Madrid &       8665 \\
# Greece & Athina &       7379 \\
# Portugal & Lisboa &       6946 \\
# United States & Chicago &       6735 \\
# Germany & Haina (Kloster) &       5973 \\
# United States & San Jose &       5427 \\
#               & Wilmington &       5403 \\
#               & Buffalo &       5038 \\
# Spain & Barcelona &       4854 \\
# United States & Potwin &       4643 \\
# \bottomrule
# \end{tabular}

# %%
N.loc[:,("country","city","Downloads")].groupby(['country']).count().sort_values(by='Downloads',ascending = False).head(15)
# Out:
#                   city  Downloads
# country
# United States   109912     110440
# France           40597      40649
# Spain            30446      30446
# United Kingdom   28340      28376
# Germany          27904      27907
# Italy            25692      25692
# Canada           25236      25237
# Netherlands      20280      20280
# Portugal         15985      16859
# Greece           10457      10513
# Poland           10356      10356
# Romania          10138      10138
# Switzerland       7595       7595
# Ukraine           7580       7582
# Belgium           7374       7374

# %%
bar1 = table1.reset_index()
plt.subplots(figsize=(15,10))
sns.set_style('darkgrid')
plt.xticks(rotation=90)
bar1 = sns.barplot('Downloads', "country", data= bar1)
bar1.set_ylabel("Downloads", fontsize=12)
bar1.set_xlabel(" ", fontsize=20)
# Out:
# Text(0.5,0,' ')

# %%
table1.plot.pie()

# %% [markdown]
# ### Top percapita Countries Deep Analaysis

# %%
N.groupby("country").count().sort_values(by="Downloads", ascending=False).head(10)
# Out:
#                 Downloads    IPID    city    date   is_oa     lat     lon  \
# country
# United States      110440  110440  109912  110440  109287  109912  109912
# France              40649   40649   40597   40649   40116   40591   40591
# Spain               30446   30446   30446   30446   30003   30446   30446
# United Kingdom      28376   28376   28340   28376   28007   28359   28359
# Germany             27907   27907   27904   27907   27450   27902   27902
# Italy               25692   25692   25692   25692   25274   25692   25692
# Canada              25237   25237   25236   25237   24998   25237   25237
# Netherlands         20280   20280   20280   20280   20069   20280   20280
# Portugal            16859   16859   15985   16859   16617   15985   15985
# Greece              10513   10513   10457   10513   10256   10513   10513
#
#                 userID  continent  DOI_prefix
# country
# United States   110440     110440      110440
# ...

# %%
N.loc[N.country == "Luxembourg",:].groupby("city").count().sort_values(by="Downloads", ascending=False).head(5)
# Out:
#                   Downloads  IPID  country  date  is_oa   lat   lon  userID  \
# city
# Schoos                 1038  1038     1038  1038   1035  1038  1038    1038
# Luxembourg              159   159      159   159    157   159   159     159
# Esch-sur-Alzette         95    95       95    95     94    95    95      95
# Mersch                   54    54       54    54     51    54    54      54
# Strassen                 26    26       26    26     26    26    26      26
#
#                   continent  DOI_prefix
# city
# Schoos                 1038        1038
# Luxembourg              159         159
# Esch-sur-Alzette         95          95
# Mersch                   54          54
# Strassen                 26          26

# %%
N.loc[N.city == "Schoos",:].groupby("IPID").count().sort_values(by="Downloads", ascending=False).head()
# Out:
#          Downloads  city  country  date  is_oa  lat  lon  userID  continent  \
# IPID
# 3212           127   127      127   127    127  127  127     127        127
# 5994895        125   125      125   125    125  125  125     125        125
# 5994630        123   123      123   123    122  123  123     123        123
# 5995403        117   117      117   117    117  117  117     117        117
# 48965          114   114      114   114    114  114  114     114        114
#
#          DOI_prefix
# IPID
# 3212            127
# 5994895         125
# 5994630         123
# 5995403         117
# 48965           114

# %%
N.loc[N.country == "Iceland",:].groupby("city").count().sort_values(by="Downloads",ascending = False).head()
# Out:
#                Downloads  IPID  country  date  is_oa  lat  lon  userID  \
# city
# Reykjavík            238   238      238   238    235  130  130     238
# Kópavogur             30    30       30    30     30   19   19      30
# Akureyri               5     5        5     5      5    3    3       5
# Hafnarfjörður          3     3        3     3      3    2    2       3
# Keflavík               2     2        2     2      2    2    2       2
#
#                continent  DOI_prefix
# city
# Reykjavík            238         238
# Kópavogur             30          30
# Akureyri               5           5
# Hafnarfjörður          3           3
# Keflavík               2           2

# %%
N.loc[N.country == "Iceland",:].groupby("IPID").count().sort_values(by="Downloads", ascending=False).head()
# Out:
#          Downloads  city  country  date  is_oa  lat  lon  userID  continent  \
# IPID
# 233088         112     0      112   112    111    0    0     112        112
# 1740127         93     0       93    93     93   93   93      93         93
# 196839          17    17       17    17     17    0    0      17         17
# 10697           11     0       11    11     11    0    0      11         11
# 875865          10    10       10    10     10   10   10      10         10
#
#          DOI_prefix
# IPID
# 233088          112
# 1740127          93
# 196839           17
# 10697            11
# 875865           10

# %%
N.loc[N.country == "Portugal",:].groupby("city").count().sort_values(by="Downloads",ascending = False).head()
# Out:
#                       Downloads  IPID  country  date  is_oa   lat   lon  \
# city
# Lisboa                     6946  6946     6946  6946   6845  6946  6946
# Porto                      1843  1843     1843  1843   1820  1843  1843
# Braga                       799   799      799   799    791   799   799
# Aveiro                      671   671      671   671    663   671   671
# São Domingos de Rana        207   207      207   207    204   207   207
#
#                       userID  continent  DOI_prefix
# city
# Lisboa                  6946       6946        6946
# Porto                   1843       1843        1843
# Braga                    799        799         799
# Aveiro                   671        671         671
# São Domingos de Rana     207        207         207

# %%
N.loc[N.country == "Portugal",:].groupby("IPID").count().sort_values(by="Downloads",ascending = False).head()
# Out:
#         Downloads  city  country  date  is_oa  lat  lon  userID  continent  \
# IPID
# 22398         148   148      148   148    145  148  148     148        148
# 174707        137   137      137   137    137  137  137     137        137
# 17920         123   123      123   123    122  123  123     123        123
# 137            99    99       99    99     98   99   99      99         99
# 88248          87    87       87    87     86   87   87      87         87
#
#         DOI_prefix
# IPID
# 22398          148
# 174707         137
# 17920          123
# 137             99
# 88248           87

# %%
statistics2017.groupby("IPID").count().sort_values(by="Downloads",ascending = False).count()
# Out:
# Downloads     829468
# city          829468
# country       829468
# date          829468
# is_oa         829468
# lat           829468
# lon           829468
# userID        829468
# continent     829468
# DOI_prefix    829468
# dtype: int64

# %% [markdown]
# ### RATIO OPERATIONS

# %%
#Sample IPID ratio
829468/1500000
# Out:
# 0.5529786666666666

# %%
#Luxembourg IPID ratio
174/1403
# Out:
# 0.1240199572344975

# %%
# Schoos IPID ratio
46/1038
# Out:
# 0.04431599229287091

# %%
#Luxembourg - Schoos IPID ratio

# %%
(174 - 46)/(1403-1038)
# Out:
# 0.3506849315068493

# %% [markdown]
# ### IPID INQUIRE ANALYSIS

# %%
statistics2017.loc[statistics2017.IPID == 3212,:].head()
# Out:
#                         Downloads  IPID    city     country  \
# 687875  10.1142/s0219607711000699  3212  Schoos  Luxembourg
# 687976  10.1142/s021947750400163x  3212  Schoos  Luxembourg
# 689137  10.1142/s0219843608001418  3212  Schoos  Luxembourg
# 691256  10.1142/s0217979200001394  3212  Schoos  Luxembourg
# 691258  10.1142/s0217979200000583  3212  Schoos  Luxembourg
#
#                        date is_oa       lat     lon    userID continent  \
# 687875  2017-06-30 20:53:59     f  49.75021  6.1688  17720151    Europe
# 687976  2017-06-30 21:23:14     f  49.75021  6.1688  17725861    Europe
# 689137  2017-07-01 04:06:31     t  49.75021  6.1688  17799455    Europe
# 691256  2017-07-01 13:57:43     f  49.75021  6.1688  17922628    Europe
# 691258  2017-07-01 13:58:19     f  49.75021  6.1688  17922715    Europe
#
#         DOI_prefix
# 687875     10.1142
# 687976     10.1142
# 689137     10.1142
# 691256     10.1142
# 691258     10.1142

# %%
statistics2017.loc[statistics2017.IPID == 5994895].sort_values("date").head()
# Out:
#                            Downloads     IPID    city     country  \
# 438706             10.1149/1.2335848  5994895  Schoos  Luxembourg
# 483391  10.1016/j.edurev.2008.11.002  5994895  Schoos  Luxembourg
# 492634            10.1039/c1dt11645b  5994895  Schoos  Luxembourg
# 508070            10.1007/bf00420192  5994895  Schoos  Luxembourg
# 530954           10.1021/j150562a004  5994895  Schoos  Luxembourg
#
#                        date is_oa       lat     lon    userID continent  \
# 438706  2017-05-06 02:01:19     f  49.75021  6.1688   9643185    Europe
# 483391  2017-05-15 20:49:12     f  49.75021  6.1688  10959417    Europe
# 492634  2017-05-17 15:55:34     f  49.75021  6.1688  11228008    Europe
# 508070  2017-05-21 09:01:30     f  49.75021  6.1688  11692447    Europe
# 530954  2017-05-26 01:50:35     f  49.75021  6.1688  12257386    Europe
#
#         DOI_prefix
# 438706     10.1149
# 483391     10.1016
# 492634     10.1039
# 508070     10.1007
# 530954     10.1021

# %%
statistics2017.loc[statistics2017.IPID == 5994630].sort_values("date").head()
# Out:
#                       Downloads     IPID    city     country  \
# 411775        10.1149/1.2059329  5994630  Schoos  Luxembourg
# 412558  10.1002/pssa.2210480135  5994630  Schoos  Luxembourg
# 426348        10.1021/jp809992g  5994630  Schoos  Luxembourg
# 437769        10.1021/cm301816t  5994630  Schoos  Luxembourg
# 463827        10.1021/jz201710z  5994630  Schoos  Luxembourg
#
#                        date is_oa       lat     lon    userID continent  \
# 411775  2017-04-30 07:59:11     f  49.75021  6.1688   8896641    Europe
# 412558  2017-04-30 13:14:55     f  49.75021  6.1688   8922390    Europe
# 426348  2017-05-03 12:57:32     f  49.75021  6.1688   9310391    Europe
# 437769  2017-05-05 19:20:29     f  49.75021  6.1688   9612975    Europe
# 463827  2017-05-11 11:53:27     f  49.75021  6.1688  10375091    Europe
#
#         DOI_prefix
# 411775     10.1149
# 412558     10.1002
# 426348     10.1021
# 437769     10.1021
# 463827     10.1021

# %%
a =statistics2017.userID.unique()
len(a)
# Out:
# 1202496
