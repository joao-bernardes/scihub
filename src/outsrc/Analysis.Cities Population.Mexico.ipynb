# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Import DataFrame

# %%
statistics2017 = pd.read_csv("./../../data/cities-population-downloads.csv")

# %%
plot = statistics2017.loc[statistics2017.country == "Mexico",:].sort_values(by="1000hb_city",ascending = False).head(25)

# %%
plot
# Out:
#       city_pop country                       city  Downloads  1000hb_city
# 532     2927.0  Mexico             Ciudad Hidalgo        191    65.254527
# 668     4053.0  Mexico                   Victoria        138    34.048853
# 715     3630.0  Mexico                     Oaxaca        122    33.608815
# 438     9436.0  Mexico           Ejido del Centro        247    26.176346
# 66     90839.0  Mexico          Ciudad Cuauhtémoc       2256    24.835148
# 863     4109.0  Mexico                    Uruapan         94    22.876612
# 530    11895.0  Mexico                   Balancán        192    16.141236
# 865     6154.0  Mexico                    Temoaya         94    15.274618
# 836     7888.0  Mexico                    Orizaba         97    12.297160
# 851     8920.0  Mexico             Pedro Escobedo         95    10.650224
# 918    10595.0  Mexico                   Saucillo         83     7.833884
# 926    12677.0  Mexico                   Tarimoro         82     6.468407
# ...

# %%
plt.subplots(figsize=(15,10))
plot = sns.barplot('1000hb_city', "city", data= plot)
plot.set_ylabel("Downloads p/1000 hab.")
plot.set_xlabel(" ", fontsize=20)
sns.set_style('darkgrid')

# %%
statistics2017.loc[statistics2017.city == "Ciudad Hidalgo",:]
# Out:
#      city_pop country            city  Downloads  1000hb_city
# 532    2927.0  Mexico  Ciudad Hidalgo        191    65.254527
